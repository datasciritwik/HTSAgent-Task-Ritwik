# %% [markdown]
# ## Loading chapter 1

# %%
import pymupdf # imports the pymupdf library
import os
path = "../data/raw/Chapter 1.pdf"# path to the PDF file
if os.path.exists(path):
    print("File exists, proceeding to open it.")
# Out:
# File exists, proceeding to open it.

# %%
doc = pymupdf.open(path) # open a document
for page in doc: # iterate the document pages
  text = page.get_text()

# %%
print(text) # print the text of the page
# Out:
# 1/ See 9903.88.15.
# Harmonized Tariff Schedule of the United States Revision 14 (2025)
# Annotated for Statistical Reporting Purposes
# I
# Endnotes--page 1 - 8

# %%
import pdfplumber
import pandas as pd
import re

# %%
def clean_text(text):
    """Cleans cell text: replaces None with '', strips whitespace, replaces newlines."""
    if text is None:
        return ""
    return str(text).replace('\n', ' ').strip()

def remove_footnote_markers(text):
    """Removes footnote markers like 1/, 2/ etc."""
    if text is None:
        return ""
    # Regex to find a number followed by a slash, possibly with spaces
    return re.sub(r'\s*\d+/\s*', '', str(text)).strip()

def extract_hts_data(pdf_path, start_page_idx, end_page_idx):
    """
    Extracts HTS data from specified pages of a PDF.

    Args:
        pdf_path (str): Path to the PDF file.
        start_page_idx (int): 0-indexed start page.
        end_page_idx (int): 0-indexed end page.

    Returns:
        pandas.DataFrame: Extracted data.
    """
    all_rows_data = []
    # Define expected column headers based on visual inspection
    # Note: "Rates of Duty" is split, so we'll have more effective columns
    column_headers = [
        "Heading/Subheading",
        "Stat. Suffix",
        "Article Description",
        "Unit of Quantity",
        "Rates of Duty - General",
        "Rates of Duty - Special",
        "Rates of Duty - 2"
    ]

    current_main_heading = "" # To carry forward e.g., "0101"
    current_subheading_base = "" # To carry forward e.g., "0101.21.00" for stat. suffixes

    with pdfplumber.open(pdf_path) as pdf:
        for i in range(start_page_idx, end_page_idx + 1):
            if i >= len(pdf.pages):
                print(f"Warning: Page index {i} is out of bounds for the PDF.")
                continue
            
            page = pdf.pages[i]
            print(f"Processing page {i+1}...")

            # Use conservative table extraction settings
            # We might need to adjust these based on the PDF's specific structure
            table = page.extract_table(table_settings={
                "vertical_strategy": "lines_strict", # Use explicit vertical lines
                "horizontal_strategy": "lines_strict", # Use explicit horizontal lines
                "snap_tolerance": 5, # Tolerance for snapping to lines
                "join_tolerance": 5, # Tolerance for joining words
            })
            
            if not table:
                # Fallback if strict lines don't work, try text-based alignment
                table = page.extract_table(table_settings={
                    "vertical_strategy": "text",
                    "horizontal_strategy": "text",
                    "snap_tolerance": 5,
                    "join_tolerance": 5,
                })

            if not table:
                print(f"No table found on page {i+1} with current settings.")
                continue

            # The first row of the first processed page is usually the header
            # We are manually defining headers for robustness.
            # Skip actual header rows found in the table.
            
            is_first_data_row_on_page = True
            if page.page_number == start_page_idx + 1: # If it's the very first page of interest
                 # Skip the actual PDF header row if present in the extracted table
                if table and "Heading/" in clean_text(table[0][0]):
                    table = table[1:]
                    is_first_data_row_on_page = False


            for row_idx, raw_row in enumerate(table):
                # Check if it's a header row based on content and skip
                if "Heading/" in clean_text(raw_row[0]) or "Article Description" in clean_text(raw_row[2]):
                    if not (is_first_data_row_on_page and row_idx == 0 and page.page_number == start_page_idx + 1):
                        continue # Skip subsequent header rows

                cleaned_row = [clean_text(cell) for cell in raw_row]

                # Ensure row has enough columns, pad with empty strings if not
                while len(cleaned_row) < len(column_headers):
                    cleaned_row.append("")

                # Heuristic to identify data rows vs. sub-headers or empty lines
                # A data row usually has content in Article Description or Stat. Suffix or Rates
                if not any(cleaned_row[1:]): # If all cells after the first are empty
                    # Could be a main heading like "0101" or noise, let's try to capture it
                    potential_main_heading = cleaned_row[0]
                    if re.match(r'^\d{4}$', potential_main_heading) or \
                       re.match(r'^\d{4}\s*\(con\.\)$', potential_main_heading):
                        current_main_heading = potential_main_heading.replace('(con.)','').strip()
                        current_subheading_base = "" # Reset subheading base
                    continue

                # Handle combined Heading/Subheading and Stat. Suffix
                hs_text = cleaned_row[0]
                stat_suffix = cleaned_row[1]
                article_desc = remove_footnote_markers(cleaned_row[2])
                unit_qty = remove_footnote_markers(cleaned_row[3])
                rate_general = remove_footnote_markers(cleaned_row[4])
                rate_special = remove_footnote_markers(cleaned_row[5])
                rate_2 = remove_footnote_markers(cleaned_row[6])

                # Logic to construct full subheading
                full_subheading = ""

                if re.match(r'^\d{4}\.\d{2}\.\d{2}$', hs_text): # e.g., 0101.21.00
                    full_subheading = hs_text
                    current_main_heading = hs_text[:4]
                    current_subheading_base = hs_text
                elif re.match(r'^\d{4}$', hs_text): # e.g. 0101
                    current_main_heading = hs_text
                    # This row might be just the heading, description might be for its children
                    # Or it might be a general entry. Let's assume description belongs to it if present.
                    if not stat_suffix and article_desc:
                         full_subheading = current_main_heading # Or treat as placeholder
                elif hs_text: # Potentially just a suffix like ".29.00"
                    if current_main_heading and re.match(r'^\s*\.\d{2}\.\d{2}$', hs_text.replace(current_main_heading, '').strip()):
                        full_subheading = current_main_heading + hs_text.replace(current_main_heading, '').strip()
                        current_subheading_base = full_subheading
                    elif current_main_heading and not stat_suffix: # If it's like "Other..." under 0101
                         pass # full_subheading remains empty, will be inferred or context dependent

                if not full_subheading and stat_suffix and current_subheading_base:
                    # This is a statistical breakdown for the current_subheading_base
                    full_subheading = current_subheading_base
                elif not full_subheading and current_main_heading: # Default to main if nothing more specific
                    full_subheading = current_main_heading


                # Skip if no meaningful data after processing
                if not full_subheading and not stat_suffix and not article_desc:
                    continue
                
                # Consolidate Article Description if it's a continuation
                # (This can be tricky; pdfplumber often handles multiline cells correctly)
                # For now, we assume pdfplumber gives the full cell content.

                # If "Article Description" is empty but we have a suffix, it usually implies "Other" or inherits
                if stat_suffix and not article_desc and all_rows_data:
                    # Check if previous row was the parent subheading
                    prev_row = all_rows_data[-1]
                    if prev_row["Heading/Subheading"] == full_subheading and not prev_row["Stat. Suffix"]:
                         # Inherit from parent, or more commonly it's an "Other" category for that suffix
                         if "Other" in prev_row["Article Description"]: # If parent was "Other"
                             article_desc = f"Other ({stat_suffix})" # Be more specific
                         elif len(stat_suffix) == 2 and stat_suffix.isdigit(): # Common pattern
                             article_desc = "Other"

                # Special handling for "Cattle: (con.)" etc.
                if "(con.)" in hs_text and article_desc and not all_rows_data:
                     # This is likely a continuation of a previous item from another section or chapter start
                     article_desc = f"{hs_text} {article_desc}"
                elif "(con.)" in hs_text and all_rows_data:
                    # Try to prepend the relevant part of article description from a suitable parent
                    # This requires more complex state tracking. For now, just include "(con.)"
                    if not article_desc: # If the description itself is empty on a con. line
                        # Look for the last non-empty article description associated with the current_main_heading or base
                        for k in range(len(all_rows_data) -1, -1, -1):
                            if all_rows_data[k]["Heading/Subheading"].startswith(current_main_heading) and \
                               all_rows_data[k]["Article Description"]:
                                article_desc = f"{all_rows_data[k]['Article Description'].split(':')[0]}: (con.)"
                                break
                    else:
                        article_desc = f"{hs_text.split(':')[0] if ':' in hs_text else current_main_heading}: (con.) {article_desc}"


                # Special case for 0102 (con.) and similar on page 5
                # if current_main_heading and clean_text(raw_row[0]).endswith("(con.)") and not article_desc:
                #    # Try to find the base article description
                #    base_desc_found = False
                #    for k_prev in range(len(all_rows_data)-1, -1, -1):
                #        if all_rows_data[k_prev]["Heading/Subheading"].startswith(current_main_heading) and \
                #           ":" in all_rows_data[k_prev]["Article Description"]:
                #            article_desc = all_rows_data[k_prev]["Article Description"].split(":")[0] + ": (con.)"
                #            base_desc_found = True
                #            break
                #    if not base_desc_found:
                #        article_desc = f"{current_main_heading} (con.)"

                # Check for "Other" lines that belong to a previous heading.
                # Example: Under "0101.29.00 Other..."
                # Then "10 Imported for immediate slaughter."
                # Then "90 Other"
                # This "90 Other" should have a more specific article description if possible
                if stat_suffix and article_desc.lower() == "other" and all_rows_data:
                    parent_description = ""
                    # Look for the description of the parent subheading (no stat suffix)
                    for k_prev_row in range(len(all_rows_data)-1, -1, -1):
                        if all_rows_data[k_prev_row]["Heading/Subheading"] == full_subheading and \
                           not all_rows_data[k_prev_row]["Stat. Suffix"] and \
                           all_rows_data[k_prev_row]["Article Description"]:
                            parent_description = all_rows_data[k_prev_row]["Article Description"]
                            break
                    if parent_description and not parent_description.lower().endswith("other"):
                         article_desc = f"{parent_description} - Other"


                # Only add if there's some substance
                if full_subheading or stat_suffix or article_desc or rate_general:
                    all_rows_data.append({
                        "Heading/Subheading": full_subheading,
                        "Stat. Suffix": stat_suffix,
                        "Article Description": article_desc,
                        "Unit of Quantity": unit_qty,
                        "Rates of Duty - General": rate_general,
                        "Rates of Duty - Special": rate_special,
                        "Rates of Duty - 2": rate_2
                    })
                is_first_data_row_on_page = False


    return pd.DataFrame(all_rows_data, columns=column_headers)

# %%
# Page numbers from your document (1-indexed in PDF, 0-indexed for pdfplumber)
# Page 4 is index 3, Page 9 is index 8
start_page_human = 1
end_page_human = 4430

df_hts = extract_hts_data(path, start_page_human - 1, end_page_human - 1)

# Post-processing: remove rows that are entirely empty or just placeholders
df_hts.dropna(how='all', subset=df_hts.columns[1:], inplace=True) # Check all but first col
df_hts = df_hts[~((df_hts['Stat. Suffix'] == '') & \
                    (df_hts['Article Description'] == '') & \
                    (df_hts['Rates of Duty - General'] == ''))]

# Fill down Heading/Subheading if it's missing but previous rows indicate a continuation context
# This part is complex due to the HTS structure. A simple ffill might be too naive.
# The current logic tries to build `full_subheading` more intelligently.

# Remove footnote markers from all columns as a final pass (if missed)
for col in df_hts.columns:
    if df_hts[col].dtype == 'object': # Apply only to string columns
        df_hts[col] = df_hts[col].apply(lambda x: remove_footnote_markers(x))

output_csv_file = "hts_extracted_data.csv"
df_hts.to_csv(output_csv_file, index=False, encoding='utf-8')

print(f"\nData extracted and saved to {output_csv_file}")
print(f"Extracted {len(df_hts)} rows.")
print("\nFirst 10 rows of extracted data:")
print(df_hts.head(10))
print("\nLast 10 rows of extracted data:")
print(df_hts.tail(10))

# %%
df = pd.read_csv(output_csv_file)
# df.style.background_gradient()
# df.style.background_gradient(cmap='viridis', subset=['Rates of Duty - General', 'Rates of Duty - Special', 'Rates of Duty - 2'])

# %%
fullpdf = "../data/raw/finalCopy.pdf"
start_page_human = 1
end_page_human = 4430

df_hts = extract_hts_data(path, start_page_human - 1, end_page_human - 1)

# Post-processing: remove rows that are entirely empty or just placeholders
df_hts.dropna(how='all', subset=df_hts.columns[1:], inplace=True) # Check all but first col
df_hts = df_hts[~((df_hts['Stat. Suffix'] == '') & \
                    (df_hts['Article Description'] == '') & \
                    (df_hts['Rates of Duty - General'] == ''))]

# Fill down Heading/Subheading if it's missing but previous rows indicate a continuation context
# This part is complex due to the HTS structure. A simple ffill might be too naive.
# The current logic tries to build `full_subheading` more intelligently.

# Remove footnote markers from all columns as a final pass (if missed)
for col in df_hts.columns:
    if df_hts[col].dtype == 'object': # Apply only to string columns
        df_hts[col] = df_hts[col].apply(lambda x: remove_footnote_markers(x))

output_csv_file = "../data/processed/fullhts_extracted_data.csv"
df_hts.to_csv(output_csv_file, index=False, encoding='utf-8')
# Out:
# Processing page 1...
# Processing page 2...
# No table found on page 2 with current settings.
# Processing page 3...
# Processing page 4...
# Processing page 5...
# Processing page 6...
# Processing page 7...
# Processing page 8...
# Processing page 9...
# Processing page 10...
# No table found on page 10 with current settings.
# Warning: Page index 10 is out of bounds for the PDF.
# Warning: Page index 11 is out of bounds for the PDF.
# Warning: Page index 12 is out of bounds for the PDF.
# Warning: Page index 13 is out of bounds for the PDF.
# Warning: Page index 14 is out of bounds for the PDF.
# Warning: Page index 15 is out of bounds for the PDF.
# Warning: Page index 16 is out of bounds for the PDF.
# Warning: Page index 17 is out of bounds for the PDF.
# Warning: Page index 18 is out of bounds for the PDF.
# Warning: Page index 19 is out of bounds for the PDF.
# Warning: Page index 20 is out of bounds for the PDF.
# Warning: Page index 21 is out of bounds for the PDF.
# Warning: Page index 22 is out of bounds for the PDF.
# Warning: Page index 23 is out of bounds for the PDF.
# Warning: Page index 24 is out of bounds for the PDF.
# Warning: Page index 25 is out of bounds for the PDF.
# Warning: Page index 26 is out of bounds for the PDF.
# Warning: Page index 27 is out of bounds for the PDF.
# Warning: Page index 28 is out of bounds for the PDF.
# Warning: Page index 29 is out of bounds for the PDF.
# Warning: Page index 30 is out of bounds for the PDF.
# Warning: Page index 31 is out of bounds for the PDF.
# Warning: Page index 32 is out of bounds for the PDF.
# Warning: Page index 33 is out of bounds for the PDF.
# Warning: Page index 34 is out of bounds for the PDF.
# Warning: Page index 35 is out of bounds for the PDF.
# Warning: Page index 36 is out of bounds for the PDF.
# Warning: Page index 37 is out of bounds for the PDF.
# Warning: Page index 38 is out of bounds for the PDF.
# Warning: Page index 39 is out of bounds for the PDF.
# Warning: Page index 40 is out of bounds for the PDF.
# Warning: Page index 41 is out of bounds for the PDF.
# Warning: Page index 42 is out of bounds for the PDF.
# Warning: Page index 43 is out of bounds for the PDF.
# Warning: Page index 44 is out of bounds for the PDF.
# Warning: Page index 45 is out of bounds for the PDF.
# Warning: Page index 46 is out of bounds for the PDF.
# Warning: Page index 47 is out of bounds for the PDF.
# Warning: Page index 48 is out of bounds for the PDF.
# Warning: Page index 49 is out of bounds for the PDF.
# Warning: Page index 50 is out of bounds for the PDF.
# Warning: Page index 51 is out of bounds for the PDF.
# Warning: Page index 52 is out of bounds for the PDF.
# Warning: Page index 53 is out of bounds for the PDF.
# Warning: Page index 54 is out of bounds for the PDF.
# Warning: Page index 55 is out of bounds for the PDF.
# Warning: Page index 56 is out of bounds for the PDF.
# Warning: Page index 57 is out of bounds for the PDF.
# Warning: Page index 58 is out of bounds for the PDF.
# Warning: Page index 59 is out of bounds for the PDF.
# Warning: Page index 60 is out of bounds for the PDF.
# Warning: Page index 61 is out of bounds for the PDF.
# Warning: Page index 62 is out of bounds for the PDF.
# Warning: Page index 63 is out of bounds for the PDF.
# Warning: Page index 64 is out of bounds for the PDF.
# Warning: Page index 65 is out of bounds for the PDF.
# Warning: Page index 66 is out of bounds for the PDF.
# Warning: Page index 67 is out of bounds for the PDF.
# Warning: Page index 68 is out of bounds for the PDF.
# Warning: Page index 69 is out of bounds for the PDF.
# Warning: Page index 70 is out of bounds for the PDF.
# Warning: Page index 71 is out of bounds for the PDF.
# Warning: Page index 72 is out of bounds for the PDF.
# Warning: Page index 73 is out of bounds for the PDF.
# Warning: Page index 74 is out of bounds for the PDF.
# Warning: Page index 75 is out of bounds for the PDF.
# Warning: Page index 76 is out of bounds for the PDF.
# Warning: Page index 77 is out of bounds for the PDF.
# Warning: Page index 78 is out of bounds for the PDF.
# Warning: Page index 79 is out of bounds for the PDF.
# Warning: Page index 80 is out of bounds for the PDF.
# Warning: Page index 81 is out of bounds for the PDF.
# Warning: Page index 82 is out of bounds for the PDF.
# Warning: Page index 83 is out of bounds for the PDF.
# Warning: Page index 84 is out of bounds for the PDF.
# Warning: Page index 85 is out of bounds for the PDF.
# Warning: Page index 86 is out of bounds for the PDF.
# Warning: Page index 87 is out of bounds for the PDF.
# Warning: Page index 88 is out of bounds for the PDF.
# Warning: Page index 89 is out of bounds for the PDF.
# Warning: Page index 90 is out of bounds for the PDF.
# Warning: Page index 91 is out of bounds for the PDF.
# Warning: Page index 92 is out of bounds for the PDF.
# Warning: Page index 93 is out of bounds for the PDF.
# Warning: Page index 94 is out of bounds for the PDF.
# Warning: Page index 95 is out of bounds for the PDF.
# Warning: Page index 96 is out of bounds for the PDF.
# Warning: Page index 97 is out of bounds for the PDF.
# Warning: Page index 98 is out of bounds for the PDF.
# Warning: Page index 99 is out of bounds for the PDF.
# Warning: Page index 100 is out of bounds for the PDF.
# Warning: Page index 101 is out of bounds for the PDF.
# Warning: Page index 102 is out of bounds for the PDF.
# Warning: Page index 103 is out of bounds for the PDF.
# Warning: Page index 104 is out of bounds for the PDF.
# Warning: Page index 105 is out of bounds for the PDF.
# Warning: Page index 106 is out of bounds for the PDF.
# Warning: Page index 107 is out of bounds for the PDF.
# Warning: Page index 108 is out of bounds for the PDF.
# Warning: Page index 109 is out of bounds for the PDF.
# Warning: Page index 110 is out of bounds for the PDF.
# Warning: Page index 111 is out of bounds for the PDF.
# Warning: Page index 112 is out of bounds for the PDF.
# Warning: Page index 113 is out of bounds for the PDF.
# Warning: Page index 114 is out of bounds for the PDF.
# Warning: Page index 115 is out of bounds for the PDF.
# Warning: Page index 116 is out of bounds for the PDF.
# Warning: Page index 117 is out of bounds for the PDF.
# Warning: Page index 118 is out of bounds for the PDF.
# Warning: Page index 119 is out of bounds for the PDF.
# Warning: Page index 120 is out of bounds for the PDF.
# Warning: Page index 121 is out of bounds for the PDF.
# Warning: Page index 122 is out of bounds for the PDF.
# Warning: Page index 123 is out of bounds for the PDF.
# Warning: Page index 124 is out of bounds for the PDF.
# Warning: Page index 125 is out of bounds for the PDF.
# Warning: Page index 126 is out of bounds for the PDF.
# Warning: Page index 127 is out of bounds for the PDF.
# Warning: Page index 128 is out of bounds for the PDF.
# Warning: Page index 129 is out of bounds for the PDF.
# Warning: Page index 130 is out of bounds for the PDF.
# Warning: Page index 131 is out of bounds for the PDF.
# Warning: Page index 132 is out of bounds for the PDF.
# Warning: Page index 133 is out of bounds for the PDF.
# Warning: Page index 134 is out of bounds for the PDF.
# Warning: Page index 135 is out of bounds for the PDF.
# Warning: Page index 136 is out of bounds for the PDF.
# Warning: Page index 137 is out of bounds for the PDF.
# Warning: Page index 138 is out of bounds for the PDF.
# Warning: Page index 139 is out of bounds for the PDF.
# Warning: Page index 140 is out of bounds for the PDF.
# Warning: Page index 141 is out of bounds for the PDF.
# Warning: Page index 142 is out of bounds for the PDF.
# Warning: Page index 143 is out of bounds for the PDF.
# Warning: Page index 144 is out of bounds for the PDF.
# Warning: Page index 145 is out of bounds for the PDF.
# Warning: Page index 146 is out of bounds for the PDF.
# Warning: Page index 147 is out of bounds for the PDF.
# Warning: Page index 148 is out of bounds for the PDF.
# Warning: Page index 149 is out of bounds for the PDF.
# Warning: Page index 150 is out of bounds for the PDF.
# Warning: Page index 151 is out of bounds for the PDF.
# Warning: Page index 152 is out of bounds for the PDF.
# Warning: Page index 153 is out of bounds for the PDF.
# Warning: Page index 154 is out of bounds for the PDF.
# Warning: Page index 155 is out of bounds for the PDF.
# Warning: Page index 156 is out of bounds for the PDF.
# Warning: Page index 157 is out of bounds for the PDF.
# Warning: Page index 158 is out of bounds for the PDF.
# Warning: Page index 159 is out of bounds for the PDF.
# Warning: Page index 160 is out of bounds for the PDF.
# Warning: Page index 161 is out of bounds for the PDF.
# Warning: Page index 162 is out of bounds for the PDF.
# Warning: Page index 163 is out of bounds for the PDF.
# Warning: Page index 164 is out of bounds for the PDF.
# Warning: Page index 165 is out of bounds for the PDF.
# Warning: Page index 166 is out of bounds for the PDF.
# Warning: Page index 167 is out of bounds for the PDF.
# Warning: Page index 168 is out of bounds for the PDF.
# Warning: Page index 169 is out of bounds for the PDF.
# Warning: Page index 170 is out of bounds for the PDF.
# Warning: Page index 171 is out of bounds for the PDF.
# Warning: Page index 172 is out of bounds for the PDF.
# Warning: Page index 173 is out of bounds for the PDF.
# Warning: Page index 174 is out of bounds for the PDF.
# Warning: Page index 175 is out of bounds for the PDF.
# Warning: Page index 176 is out of bounds for the PDF.
# Warning: Page index 177 is out of bounds for the PDF.
# Warning: Page index 178 is out of bounds for the PDF.
# Warning: Page index 179 is out of bounds for the PDF.
# Warning: Page index 180 is out of bounds for the PDF.
# Warning: Page index 181 is out of bounds for the PDF.
# Warning: Page index 182 is out of bounds for the PDF.
# Warning: Page index 183 is out of bounds for the PDF.
# Warning: Page index 184 is out of bounds for the PDF.
# Warning: Page index 185 is out of bounds for the PDF.
# Warning: Page index 186 is out of bounds for the PDF.
# Warning: Page index 187 is out of bounds for the PDF.
# Warning: Page index 188 is out of bounds for the PDF.
# Warning: Page index 189 is out of bounds for the PDF.
# Warning: Page index 190 is out of bounds for the PDF.
# Warning: Page index 191 is out of bounds for the PDF.
# Warning: Page index 192 is out of bounds for the PDF.
# Warning: Page index 193 is out of bounds for the PDF.
# Warning: Page index 194 is out of bounds for the PDF.
# Warning: Page index 195 is out of bounds for the PDF.
# Warning: Page index 196 is out of bounds for the PDF.
# Warning: Page index 197 is out of bounds for the PDF.
# Warning: Page index 198 is out of bounds for the PDF.
# Warning: Page index 199 is out of bounds for the PDF.
# Warning: Page index 200 is out of bounds for the PDF.
# Warning: Page index 201 is out of bounds for the PDF.
# Warning: Page index 202 is out of bounds for the PDF.
# Warning: Page index 203 is out of bounds for the PDF.
# Warning: Page index 204 is out of bounds for the PDF.
# Warning: Page index 205 is out of bounds for the PDF.
# Warning: Page index 206 is out of bounds for the PDF.
# Warning: Page index 207 is out of bounds for the PDF.
# Warning: Page index 208 is out of bounds for the PDF.
# Warning: Page index 209 is out of bounds for the PDF.
# Warning: Page index 210 is out of bounds for the PDF.
# Warning: Page index 211 is out of bounds for the PDF.
# Warning: Page index 212 is out of bounds for the PDF.
# Warning: Page index 213 is out of bounds for the PDF.
# Warning: Page index 214 is out of bounds for the PDF.
# Warning: Page index 215 is out of bounds for the PDF.
# Warning: Page index 216 is out of bounds for the PDF.
# Warning: Page index 217 is out of bounds for the PDF.
# Warning: Page index 218 is out of bounds for the PDF.
# Warning: Page index 219 is out of bounds for the PDF.
# Warning: Page index 220 is out of bounds for the PDF.
# Warning: Page index 221 is out of bounds for the PDF.
# Warning: Page index 222 is out of bounds for the PDF.
# Warning: Page index 223 is out of bounds for the PDF.
# Warning: Page index 224 is out of bounds for the PDF.
# Warning: Page index 225 is out of bounds for the PDF.
# Warning: Page index 226 is out of bounds for the PDF.
# Warning: Page index 227 is out of bounds for the PDF.
# Warning: Page index 228 is out of bounds for the PDF.
# Warning: Page index 229 is out of bounds for the PDF.
# Warning: Page index 230 is out of bounds for the PDF.
# Warning: Page index 231 is out of bounds for the PDF.
# Warning: Page index 232 is out of bounds for the PDF.
# Warning: Page index 233 is out of bounds for the PDF.
# Warning: Page index 234 is out of bounds for the PDF.
# Warning: Page index 235 is out of bounds for the PDF.
# Warning: Page index 236 is out of bounds for the PDF.
# Warning: Page index 237 is out of bounds for the PDF.
# Warning: Page index 238 is out of bounds for the PDF.
# Warning: Page index 239 is out of bounds for the PDF.
# Warning: Page index 240 is out of bounds for the PDF.
# Warning: Page index 241 is out of bounds for the PDF.
# Warning: Page index 242 is out of bounds for the PDF.
# Warning: Page index 243 is out of bounds for the PDF.
# Warning: Page index 244 is out of bounds for the PDF.
# Warning: Page index 245 is out of bounds for the PDF.
# Warning: Page index 246 is out of bounds for the PDF.
# Warning: Page index 247 is out of bounds for the PDF.
# Warning: Page index 248 is out of bounds for the PDF.
# Warning: Page index 249 is out of bounds for the PDF.
# Warning: Page index 250 is out of bounds for the PDF.
# Warning: Page index 251 is out of bounds for the PDF.
# Warning: Page index 252 is out of bounds for the PDF.
# Warning: Page index 253 is out of bounds for the PDF.
# Warning: Page index 254 is out of bounds for the PDF.
# Warning: Page index 255 is out of bounds for the PDF.
# Warning: Page index 256 is out of bounds for the PDF.
# Warning: Page index 257 is out of bounds for the PDF.
# Warning: Page index 258 is out of bounds for the PDF.
# Warning: Page index 259 is out of bounds for the PDF.
# Warning: Page index 260 is out of bounds for the PDF.
# Warning: Page index 261 is out of bounds for the PDF.
# Warning: Page index 262 is out of bounds for the PDF.
# Warning: Page index 263 is out of bounds for the PDF.
# Warning: Page index 264 is out of bounds for the PDF.
# Warning: Page index 265 is out of bounds for the PDF.
# Warning: Page index 266 is out of bounds for the PDF.
# Warning: Page index 267 is out of bounds for the PDF.
# Warning: Page index 268 is out of bounds for the PDF.
# Warning: Page index 269 is out of bounds for the PDF.
# Warning: Page index 270 is out of bounds for the PDF.
# Warning: Page index 271 is out of bounds for the PDF.
# Warning: Page index 272 is out of bounds for the PDF.
# Warning: Page index 273 is out of bounds for the PDF.
# Warning: Page index 274 is out of bounds for the PDF.
# Warning: Page index 275 is out of bounds for the PDF.
# Warning: Page index 276 is out of bounds for the PDF.
# Warning: Page index 277 is out of bounds for the PDF.
# Warning: Page index 278 is out of bounds for the PDF.
# Warning: Page index 279 is out of bounds for the PDF.
# Warning: Page index 280 is out of bounds for the PDF.
# Warning: Page index 281 is out of bounds for the PDF.
# Warning: Page index 282 is out of bounds for the PDF.
# Warning: Page index 283 is out of bounds for the PDF.
# Warning: Page index 284 is out of bounds for the PDF.
# Warning: Page index 285 is out of bounds for the PDF.
# Warning: Page index 286 is out of bounds for the PDF.
# Warning: Page index 287 is out of bounds for the PDF.
# Warning: Page index 288 is out of bounds for the PDF.
# Warning: Page index 289 is out of bounds for the PDF.
# Warning: Page index 290 is out of bounds for the PDF.
# Warning: Page index 291 is out of bounds for the PDF.
# Warning: Page index 292 is out of bounds for the PDF.
# Warning: Page index 293 is out of bounds for the PDF.
# Warning: Page index 294 is out of bounds for the PDF.
# Warning: Page index 295 is out of bounds for the PDF.
# Warning: Page index 296 is out of bounds for the PDF.
# Warning: Page index 297 is out of bounds for the PDF.
# Warning: Page index 298 is out of bounds for the PDF.
# Warning: Page index 299 is out of bounds for the PDF.
# Warning: Page index 300 is out of bounds for the PDF.
# Warning: Page index 301 is out of bounds for the PDF.
# Warning: Page index 302 is out of bounds for the PDF.
# Warning: Page index 303 is out of bounds for the PDF.
# Warning: Page index 304 is out of bounds for the PDF.
# Warning: Page index 305 is out of bounds for the PDF.
# Warning: Page index 306 is out of bounds for the PDF.
# Warning: Page index 307 is out of bounds for the PDF.
# Warning: Page index 308 is out of bounds for the PDF.
# Warning: Page index 309 is out of bounds for the PDF.
# Warning: Page index 310 is out of bounds for the PDF.
# Warning: Page index 311 is out of bounds for the PDF.
# Warning: Page index 312 is out of bounds for the PDF.
# Warning: Page index 313 is out of bounds for the PDF.
# Warning: Page index 314 is out of bounds for the PDF.
# Warning: Page index 315 is out of bounds for the PDF.
# Warning: Page index 316 is out of bounds for the PDF.
# Warning: Page index 317 is out of bounds for the PDF.
# Warning: Page index 318 is out of bounds for the PDF.
# Warning: Page index 319 is out of bounds for the PDF.
# Warning: Page index 320 is out of bounds for the PDF.
# Warning: Page index 321 is out of bounds for the PDF.
# Warning: Page index 322 is out of bounds for the PDF.
# Warning: Page index 323 is out of bounds for the PDF.
# Warning: Page index 324 is out of bounds for the PDF.
# Warning: Page index 325 is out of bounds for the PDF.
# Warning: Page index 326 is out of bounds for the PDF.
# Warning: Page index 327 is out of bounds for the PDF.
# Warning: Page index 328 is out of bounds for the PDF.
# Warning: Page index 329 is out of bounds for the PDF.
# Warning: Page index 330 is out of bounds for the PDF.
# Warning: Page index 331 is out of bounds for the PDF.
# Warning: Page index 332 is out of bounds for the PDF.
# Warning: Page index 333 is out of bounds for the PDF.
# Warning: Page index 334 is out of bounds for the PDF.
# Warning: Page index 335 is out of bounds for the PDF.
# Warning: Page index 336 is out of bounds for the PDF.
# Warning: Page index 337 is out of bounds for the PDF.
# Warning: Page index 338 is out of bounds for the PDF.
# Warning: Page index 339 is out of bounds for the PDF.
# Warning: Page index 340 is out of bounds for the PDF.
# Warning: Page index 341 is out of bounds for the PDF.
# Warning: Page index 342 is out of bounds for the PDF.
# Warning: Page index 343 is out of bounds for the PDF.
# Warning: Page index 344 is out of bounds for the PDF.
# Warning: Page index 345 is out of bounds for the PDF.
# Warning: Page index 346 is out of bounds for the PDF.
# Warning: Page index 347 is out of bounds for the PDF.
# Warning: Page index 348 is out of bounds for the PDF.
# Warning: Page index 349 is out of bounds for the PDF.
# Warning: Page index 350 is out of bounds for the PDF.
# Warning: Page index 351 is out of bounds for the PDF.
# Warning: Page index 352 is out of bounds for the PDF.
# Warning: Page index 353 is out of bounds for the PDF.
# Warning: Page index 354 is out of bounds for the PDF.
# Warning: Page index 355 is out of bounds for the PDF.
# Warning: Page index 356 is out of bounds for the PDF.
# Warning: Page index 357 is out of bounds for the PDF.
# Warning: Page index 358 is out of bounds for the PDF.
# Warning: Page index 359 is out of bounds for the PDF.
# Warning: Page index 360 is out of bounds for the PDF.
# Warning: Page index 361 is out of bounds for the PDF.
# Warning: Page index 362 is out of bounds for the PDF.
# Warning: Page index 363 is out of bounds for the PDF.
# Warning: Page index 364 is out of bounds for the PDF.
# Warning: Page index 365 is out of bounds for the PDF.
# Warning: Page index 366 is out of bounds for the PDF.
# Warning: Page index 367 is out of bounds for the PDF.
# Warning: Page index 368 is out of bounds for the PDF.
# Warning: Page index 369 is out of bounds for the PDF.
# Warning: Page index 370 is out of bounds for the PDF.
# Warning: Page index 371 is out of bounds for the PDF.
# Warning: Page index 372 is out of bounds for the PDF.
# Warning: Page index 373 is out of bounds for the PDF.
# Warning: Page index 374 is out of bounds for the PDF.
# Warning: Page index 375 is out of bounds for the PDF.
# Warning: Page index 376 is out of bounds for the PDF.
# Warning: Page index 377 is out of bounds for the PDF.
# Warning: Page index 378 is out of bounds for the PDF.
# Warning: Page index 379 is out of bounds for the PDF.
# Warning: Page index 380 is out of bounds for the PDF.
# Warning: Page index 381 is out of bounds for the PDF.
# Warning: Page index 382 is out of bounds for the PDF.
# Warning: Page index 383 is out of bounds for the PDF.
# Warning: Page index 384 is out of bounds for the PDF.
# Warning: Page index 385 is out of bounds for the PDF.
# Warning: Page index 386 is out of bounds for the PDF.
# Warning: Page index 387 is out of bounds for the PDF.
# Warning: Page index 388 is out of bounds for the PDF.
# Warning: Page index 389 is out of bounds for the PDF.
# Warning: Page index 390 is out of bounds for the PDF.
# Warning: Page index 391 is out of bounds for the PDF.
# Warning: Page index 392 is out of bounds for the PDF.
# Warning: Page index 393 is out of bounds for the PDF.
# Warning: Page index 394 is out of bounds for the PDF.
# Warning: Page index 395 is out of bounds for the PDF.
# Warning: Page index 396 is out of bounds for the PDF.
# Warning: Page index 397 is out of bounds for the PDF.
# Warning: Page index 398 is out of bounds for the PDF.
# Warning: Page index 399 is out of bounds for the PDF.
# Warning: Page index 400 is out of bounds for the PDF.
# Warning: Page index 401 is out of bounds for the PDF.
# Warning: Page index 402 is out of bounds for the PDF.
# Warning: Page index 403 is out of bounds for the PDF.
# Warning: Page index 404 is out of bounds for the PDF.
# Warning: Page index 405 is out of bounds for the PDF.
# Warning: Page index 406 is out of bounds for the PDF.
# Warning: Page index 407 is out of bounds for the PDF.
# Warning: Page index 408 is out of bounds for the PDF.
# Warning: Page index 409 is out of bounds for the PDF.
# Warning: Page index 410 is out of bounds for the PDF.
# Warning: Page index 411 is out of bounds for the PDF.
# Warning: Page index 412 is out of bounds for the PDF.
# Warning: Page index 413 is out of bounds for the PDF.
# Warning: Page index 414 is out of bounds for the PDF.
# Warning: Page index 415 is out of bounds for the PDF.
# Warning: Page index 416 is out of bounds for the PDF.
# Warning: Page index 417 is out of bounds for the PDF.
# Warning: Page index 418 is out of bounds for the PDF.
# Warning: Page index 419 is out of bounds for the PDF.
# Warning: Page index 420 is out of bounds for the PDF.
# Warning: Page index 421 is out of bounds for the PDF.
# Warning: Page index 422 is out of bounds for the PDF.
# Warning: Page index 423 is out of bounds for the PDF.
# Warning: Page index 424 is out of bounds for the PDF.
# Warning: Page index 425 is out of bounds for the PDF.
# Warning: Page index 426 is out of bounds for the PDF.
# Warning: Page index 427 is out of bounds for the PDF.
# Warning: Page index 428 is out of bounds for the PDF.
# Warning: Page index 429 is out of bounds for the PDF.
# Warning: Page index 430 is out of bounds for the PDF.
# Warning: Page index 431 is out of bounds for the PDF.
# Warning: Page index 432 is out of bounds for the PDF.
# Warning: Page index 433 is out of bounds for the PDF.
# Warning: Page index 434 is out of bounds for the PDF.
# Warning: Page index 435 is out of bounds for the PDF.
# Warning: Page index 436 is out of bounds for the PDF.
# Warning: Page index 437 is out of bounds for the PDF.
# Warning: Page index 438 is out of bounds for the PDF.
# Warning: Page index 439 is out of bounds for the PDF.
# Warning: Page index 440 is out of bounds for the PDF.
# Warning: Page index 441 is out of bounds for the PDF.
# Warning: Page index 442 is out of bounds for the PDF.
# Warning: Page index 443 is out of bounds for the PDF.
# Warning: Page index 444 is out of bounds for the PDF.
# Warning: Page index 445 is out of bounds for the PDF.
# Warning: Page index 446 is out of bounds for the PDF.
# Warning: Page index 447 is out of bounds for the PDF.
# Warning: Page index 448 is out of bounds for the PDF.
# Warning: Page index 449 is out of bounds for the PDF.
# Warning: Page index 450 is out of bounds for the PDF.
# Warning: Page index 451 is out of bounds for the PDF.
# Warning: Page index 452 is out of bounds for the PDF.
# Warning: Page index 453 is out of bounds for the PDF.
# Warning: Page index 454 is out of bounds for the PDF.
# Warning: Page index 455 is out of bounds for the PDF.
# Warning: Page index 456 is out of bounds for the PDF.
# Warning: Page index 457 is out of bounds for the PDF.
# Warning: Page index 458 is out of bounds for the PDF.
# Warning: Page index 459 is out of bounds for the PDF.
# Warning: Page index 460 is out of bounds for the PDF.
# Warning: Page index 461 is out of bounds for the PDF.
# Warning: Page index 462 is out of bounds for the PDF.
# Warning: Page index 463 is out of bounds for the PDF.
# Warning: Page index 464 is out of bounds for the PDF.
# Warning: Page index 465 is out of bounds for the PDF.
# Warning: Page index 466 is out of bounds for the PDF.
# Warning: Page index 467 is out of bounds for the PDF.
# Warning: Page index 468 is out of bounds for the PDF.
# Warning: Page index 469 is out of bounds for the PDF.
# Warning: Page index 470 is out of bounds for the PDF.
# Warning: Page index 471 is out of bounds for the PDF.
# Warning: Page index 472 is out of bounds for the PDF.
# Warning: Page index 473 is out of bounds for the PDF.
# Warning: Page index 474 is out of bounds for the PDF.
# Warning: Page index 475 is out of bounds for the PDF.
# Warning: Page index 476 is out of bounds for the PDF.
# Warning: Page index 477 is out of bounds for the PDF.
# Warning: Page index 478 is out of bounds for the PDF.
# Warning: Page index 479 is out of bounds for the PDF.
# Warning: Page index 480 is out of bounds for the PDF.
# Warning: Page index 481 is out of bounds for the PDF.
# Warning: Page index 482 is out of bounds for the PDF.
# Warning: Page index 483 is out of bounds for the PDF.
# Warning: Page index 484 is out of bounds for the PDF.
# Warning: Page index 485 is out of bounds for the PDF.
# Warning: Page index 486 is out of bounds for the PDF.
# Warning: Page index 487 is out of bounds for the PDF.
# Warning: Page index 488 is out of bounds for the PDF.
# Warning: Page index 489 is out of bounds for the PDF.
# Warning: Page index 490 is out of bounds for the PDF.
# Warning: Page index 491 is out of bounds for the PDF.
# Warning: Page index 492 is out of bounds for the PDF.
# Warning: Page index 493 is out of bounds for the PDF.
# Warning: Page index 494 is out of bounds for the PDF.
# Warning: Page index 495 is out of bounds for the PDF.
# Warning: Page index 496 is out of bounds for the PDF.
# Warning: Page index 497 is out of bounds for the PDF.
# Warning: Page index 498 is out of bounds for the PDF.
# Warning: Page index 499 is out of bounds for the PDF.
# Warning: Page index 500 is out of bounds for the PDF.
# Warning: Page index 501 is out of bounds for the PDF.
# Warning: Page index 502 is out of bounds for the PDF.
# Warning: Page index 503 is out of bounds for the PDF.
# Warning: Page index 504 is out of bounds for the PDF.
# Warning: Page index 505 is out of bounds for the PDF.
# Warning: Page index 506 is out of bounds for the PDF.
# Warning: Page index 507 is out of bounds for the PDF.
# Warning: Page index 508 is out of bounds for the PDF.
# Warning: Page index 509 is out of bounds for the PDF.
# Warning: Page index 510 is out of bounds for the PDF.
# Warning: Page index 511 is out of bounds for the PDF.
# Warning: Page index 512 is out of bounds for the PDF.
# Warning: Page index 513 is out of bounds for the PDF.
# Warning: Page index 514 is out of bounds for the PDF.
# Warning: Page index 515 is out of bounds for the PDF.
# Warning: Page index 516 is out of bounds for the PDF.
# Warning: Page index 517 is out of bounds for the PDF.
# Warning: Page index 518 is out of bounds for the PDF.
# Warning: Page index 519 is out of bounds for the PDF.
# Warning: Page index 520 is out of bounds for the PDF.
# Warning: Page index 521 is out of bounds for the PDF.
# Warning: Page index 522 is out of bounds for the PDF.
# Warning: Page index 523 is out of bounds for the PDF.
# Warning: Page index 524 is out of bounds for the PDF.
# Warning: Page index 525 is out of bounds for the PDF.
# Warning: Page index 526 is out of bounds for the PDF.
# Warning: Page index 527 is out of bounds for the PDF.
# Warning: Page index 528 is out of bounds for the PDF.
# Warning: Page index 529 is out of bounds for the PDF.
# Warning: Page index 530 is out of bounds for the PDF.
# Warning: Page index 531 is out of bounds for the PDF.
# Warning: Page index 532 is out of bounds for the PDF.
# Warning: Page index 533 is out of bounds for the PDF.
# Warning: Page index 534 is out of bounds for the PDF.
# Warning: Page index 535 is out of bounds for the PDF.
# Warning: Page index 536 is out of bounds for the PDF.
# Warning: Page index 537 is out of bounds for the PDF.
# Warning: Page index 538 is out of bounds for the PDF.
# Warning: Page index 539 is out of bounds for the PDF.
# Warning: Page index 540 is out of bounds for the PDF.
# Warning: Page index 541 is out of bounds for the PDF.
# Warning: Page index 542 is out of bounds for the PDF.
# Warning: Page index 543 is out of bounds for the PDF.
# Warning: Page index 544 is out of bounds for the PDF.
# Warning: Page index 545 is out of bounds for the PDF.
# Warning: Page index 546 is out of bounds for the PDF.
# Warning: Page index 547 is out of bounds for the PDF.
# Warning: Page index 548 is out of bounds for the PDF.
# Warning: Page index 549 is out of bounds for the PDF.
# Warning: Page index 550 is out of bounds for the PDF.
# Warning: Page index 551 is out of bounds for the PDF.
# Warning: Page index 552 is out of bounds for the PDF.
# Warning: Page index 553 is out of bounds for the PDF.
# Warning: Page index 554 is out of bounds for the PDF.
# Warning: Page index 555 is out of bounds for the PDF.
# Warning: Page index 556 is out of bounds for the PDF.
# Warning: Page index 557 is out of bounds for the PDF.
# Warning: Page index 558 is out of bounds for the PDF.
# Warning: Page index 559 is out of bounds for the PDF.
# Warning: Page index 560 is out of bounds for the PDF.
# Warning: Page index 561 is out of bounds for the PDF.
# Warning: Page index 562 is out of bounds for the PDF.
# Warning: Page index 563 is out of bounds for the PDF.
# Warning: Page index 564 is out of bounds for the PDF.
# Warning: Page index 565 is out of bounds for the PDF.
# Warning: Page index 566 is out of bounds for the PDF.
# Warning: Page index 567 is out of bounds for the PDF.
# Warning: Page index 568 is out of bounds for the PDF.
# Warning: Page index 569 is out of bounds for the PDF.
# Warning: Page index 570 is out of bounds for the PDF.
# Warning: Page index 571 is out of bounds for the PDF.
# Warning: Page index 572 is out of bounds for the PDF.
# Warning: Page index 573 is out of bounds for the PDF.
# Warning: Page index 574 is out of bounds for the PDF.
# Warning: Page index 575 is out of bounds for the PDF.
# Warning: Page index 576 is out of bounds for the PDF.
# Warning: Page index 577 is out of bounds for the PDF.
# Warning: Page index 578 is out of bounds for the PDF.
# Warning: Page index 579 is out of bounds for the PDF.
# Warning: Page index 580 is out of bounds for the PDF.
# Warning: Page index 581 is out of bounds for the PDF.
# Warning: Page index 582 is out of bounds for the PDF.
# Warning: Page index 583 is out of bounds for the PDF.
# Warning: Page index 584 is out of bounds for the PDF.
# Warning: Page index 585 is out of bounds for the PDF.
# Warning: Page index 586 is out of bounds for the PDF.
# Warning: Page index 587 is out of bounds for the PDF.
# Warning: Page index 588 is out of bounds for the PDF.
# Warning: Page index 589 is out of bounds for the PDF.
# Warning: Page index 590 is out of bounds for the PDF.
# Warning: Page index 591 is out of bounds for the PDF.
# Warning: Page index 592 is out of bounds for the PDF.
# Warning: Page index 593 is out of bounds for the PDF.
# Warning: Page index 594 is out of bounds for the PDF.
# Warning: Page index 595 is out of bounds for the PDF.
# Warning: Page index 596 is out of bounds for the PDF.
# Warning: Page index 597 is out of bounds for the PDF.
# Warning: Page index 598 is out of bounds for the PDF.
# Warning: Page index 599 is out of bounds for the PDF.
# Warning: Page index 600 is out of bounds for the PDF.
# Warning: Page index 601 is out of bounds for the PDF.
# Warning: Page index 602 is out of bounds for the PDF.
# Warning: Page index 603 is out of bounds for the PDF.
# Warning: Page index 604 is out of bounds for the PDF.
# Warning: Page index 605 is out of bounds for the PDF.
# Warning: Page index 606 is out of bounds for the PDF.
# Warning: Page index 607 is out of bounds for the PDF.
# Warning: Page index 608 is out of bounds for the PDF.
# Warning: Page index 609 is out of bounds for the PDF.
# Warning: Page index 610 is out of bounds for the PDF.
# Warning: Page index 611 is out of bounds for the PDF.
# Warning: Page index 612 is out of bounds for the PDF.
# Warning: Page index 613 is out of bounds for the PDF.
# Warning: Page index 614 is out of bounds for the PDF.
# Warning: Page index 615 is out of bounds for the PDF.
# Warning: Page index 616 is out of bounds for the PDF.
# Warning: Page index 617 is out of bounds for the PDF.
# Warning: Page index 618 is out of bounds for the PDF.
# Warning: Page index 619 is out of bounds for the PDF.
# Warning: Page index 620 is out of bounds for the PDF.
# Warning: Page index 621 is out of bounds for the PDF.
# Warning: Page index 622 is out of bounds for the PDF.
# Warning: Page index 623 is out of bounds for the PDF.
# Warning: Page index 624 is out of bounds for the PDF.
# Warning: Page index 625 is out of bounds for the PDF.
# Warning: Page index 626 is out of bounds for the PDF.
# Warning: Page index 627 is out of bounds for the PDF.
# Warning: Page index 628 is out of bounds for the PDF.
# Warning: Page index 629 is out of bounds for the PDF.
# Warning: Page index 630 is out of bounds for the PDF.
# Warning: Page index 631 is out of bounds for the PDF.
# Warning: Page index 632 is out of bounds for the PDF.
# Warning: Page index 633 is out of bounds for the PDF.
# Warning: Page index 634 is out of bounds for the PDF.
# Warning: Page index 635 is out of bounds for the PDF.
# Warning: Page index 636 is out of bounds for the PDF.
# Warning: Page index 637 is out of bounds for the PDF.
# Warning: Page index 638 is out of bounds for the PDF.
# Warning: Page index 639 is out of bounds for the PDF.
# Warning: Page index 640 is out of bounds for the PDF.
# Warning: Page index 641 is out of bounds for the PDF.
# Warning: Page index 642 is out of bounds for the PDF.
# Warning: Page index 643 is out of bounds for the PDF.
# Warning: Page index 644 is out of bounds for the PDF.
# Warning: Page index 645 is out of bounds for the PDF.
# Warning: Page index 646 is out of bounds for the PDF.
# Warning: Page index 647 is out of bounds for the PDF.
# Warning: Page index 648 is out of bounds for the PDF.
# Warning: Page index 649 is out of bounds for the PDF.
# Warning: Page index 650 is out of bounds for the PDF.
# Warning: Page index 651 is out of bounds for the PDF.
# Warning: Page index 652 is out of bounds for the PDF.
# Warning: Page index 653 is out of bounds for the PDF.
# Warning: Page index 654 is out of bounds for the PDF.
# Warning: Page index 655 is out of bounds for the PDF.
# Warning: Page index 656 is out of bounds for the PDF.
# Warning: Page index 657 is out of bounds for the PDF.
# Warning: Page index 658 is out of bounds for the PDF.
# Warning: Page index 659 is out of bounds for the PDF.
# Warning: Page index 660 is out of bounds for the PDF.
# Warning: Page index 661 is out of bounds for the PDF.
# Warning: Page index 662 is out of bounds for the PDF.
# Warning: Page index 663 is out of bounds for the PDF.
# Warning: Page index 664 is out of bounds for the PDF.
# Warning: Page index 665 is out of bounds for the PDF.
# Warning: Page index 666 is out of bounds for the PDF.
# Warning: Page index 667 is out of bounds for the PDF.
# Warning: Page index 668 is out of bounds for the PDF.
# Warning: Page index 669 is out of bounds for the PDF.
# Warning: Page index 670 is out of bounds for the PDF.
# Warning: Page index 671 is out of bounds for the PDF.
# Warning: Page index 672 is out of bounds for the PDF.
# Warning: Page index 673 is out of bounds for the PDF.
# Warning: Page index 674 is out of bounds for the PDF.
# Warning: Page index 675 is out of bounds for the PDF.
# Warning: Page index 676 is out of bounds for the PDF.
# Warning: Page index 677 is out of bounds for the PDF.
# Warning: Page index 678 is out of bounds for the PDF.
# Warning: Page index 679 is out of bounds for the PDF.
# Warning: Page index 680 is out of bounds for the PDF.
# Warning: Page index 681 is out of bounds for the PDF.
# Warning: Page index 682 is out of bounds for the PDF.
# Warning: Page index 683 is out of bounds for the PDF.
# Warning: Page index 684 is out of bounds for the PDF.
# Warning: Page index 685 is out of bounds for the PDF.
# Warning: Page index 686 is out of bounds for the PDF.
# Warning: Page index 687 is out of bounds for the PDF.
# Warning: Page index 688 is out of bounds for the PDF.
# Warning: Page index 689 is out of bounds for the PDF.
# Warning: Page index 690 is out of bounds for the PDF.
# Warning: Page index 691 is out of bounds for the PDF.
# Warning: Page index 692 is out of bounds for the PDF.
# Warning: Page index 693 is out of bounds for the PDF.
# Warning: Page index 694 is out of bounds for the PDF.
# Warning: Page index 695 is out of bounds for the PDF.
# Warning: Page index 696 is out of bounds for the PDF.
# Warning: Page index 697 is out of bounds for the PDF.
# Warning: Page index 698 is out of bounds for the PDF.
# Warning: Page index 699 is out of bounds for the PDF.
# Warning: Page index 700 is out of bounds for the PDF.
# Warning: Page index 701 is out of bounds for the PDF.
# Warning: Page index 702 is out of bounds for the PDF.
# Warning: Page index 703 is out of bounds for the PDF.
# Warning: Page index 704 is out of bounds for the PDF.
# Warning: Page index 705 is out of bounds for the PDF.
# Warning: Page index 706 is out of bounds for the PDF.
# Warning: Page index 707 is out of bounds for the PDF.
# Warning: Page index 708 is out of bounds for the PDF.
# Warning: Page index 709 is out of bounds for the PDF.
# Warning: Page index 710 is out of bounds for the PDF.
# Warning: Page index 711 is out of bounds for the PDF.
# Warning: Page index 712 is out of bounds for the PDF.
# Warning: Page index 713 is out of bounds for the PDF.
# Warning: Page index 714 is out of bounds for the PDF.
# Warning: Page index 715 is out of bounds for the PDF.
# Warning: Page index 716 is out of bounds for the PDF.
# Warning: Page index 717 is out of bounds for the PDF.
# Warning: Page index 718 is out of bounds for the PDF.
# Warning: Page index 719 is out of bounds for the PDF.
# Warning: Page index 720 is out of bounds for the PDF.
# Warning: Page index 721 is out of bounds for the PDF.
# Warning: Page index 722 is out of bounds for the PDF.
# Warning: Page index 723 is out of bounds for the PDF.
# Warning: Page index 724 is out of bounds for the PDF.
# Warning: Page index 725 is out of bounds for the PDF.
# Warning: Page index 726 is out of bounds for the PDF.
# Warning: Page index 727 is out of bounds for the PDF.
# Warning: Page index 728 is out of bounds for the PDF.
# Warning: Page index 729 is out of bounds for the PDF.
# Warning: Page index 730 is out of bounds for the PDF.
# Warning: Page index 731 is out of bounds for the PDF.
# Warning: Page index 732 is out of bounds for the PDF.
# Warning: Page index 733 is out of bounds for the PDF.
# Warning: Page index 734 is out of bounds for the PDF.
# Warning: Page index 735 is out of bounds for the PDF.
# Warning: Page index 736 is out of bounds for the PDF.
# Warning: Page index 737 is out of bounds for the PDF.
# Warning: Page index 738 is out of bounds for the PDF.
# Warning: Page index 739 is out of bounds for the PDF.
# Warning: Page index 740 is out of bounds for the PDF.
# Warning: Page index 741 is out of bounds for the PDF.
# Warning: Page index 742 is out of bounds for the PDF.
# Warning: Page index 743 is out of bounds for the PDF.
# Warning: Page index 744 is out of bounds for the PDF.
# Warning: Page index 745 is out of bounds for the PDF.
# Warning: Page index 746 is out of bounds for the PDF.
# Warning: Page index 747 is out of bounds for the PDF.
# Warning: Page index 748 is out of bounds for the PDF.
# Warning: Page index 749 is out of bounds for the PDF.
# Warning: Page index 750 is out of bounds for the PDF.
# Warning: Page index 751 is out of bounds for the PDF.
# Warning: Page index 752 is out of bounds for the PDF.
# Warning: Page index 753 is out of bounds for the PDF.
# Warning: Page index 754 is out of bounds for the PDF.
# Warning: Page index 755 is out of bounds for the PDF.
# Warning: Page index 756 is out of bounds for the PDF.
# Warning: Page index 757 is out of bounds for the PDF.
# Warning: Page index 758 is out of bounds for the PDF.
# Warning: Page index 759 is out of bounds for the PDF.
# Warning: Page index 760 is out of bounds for the PDF.
# Warning: Page index 761 is out of bounds for the PDF.
# Warning: Page index 762 is out of bounds for the PDF.
# Warning: Page index 763 is out of bounds for the PDF.
# Warning: Page index 764 is out of bounds for the PDF.
# Warning: Page index 765 is out of bounds for the PDF.
# Warning: Page index 766 is out of bounds for the PDF.
# Warning: Page index 767 is out of bounds for the PDF.
# Warning: Page index 768 is out of bounds for the PDF.
# Warning: Page index 769 is out of bounds for the PDF.
# Warning: Page index 770 is out of bounds for the PDF.
# Warning: Page index 771 is out of bounds for the PDF.
# Warning: Page index 772 is out of bounds for the PDF.
# Warning: Page index 773 is out of bounds for the PDF.
# Warning: Page index 774 is out of bounds for the PDF.
# Warning: Page index 775 is out of bounds for the PDF.
# Warning: Page index 776 is out of bounds for the PDF.
# Warning: Page index 777 is out of bounds for the PDF.
# Warning: Page index 778 is out of bounds for the PDF.
# Warning: Page index 779 is out of bounds for the PDF.
# Warning: Page index 780 is out of bounds for the PDF.
# Warning: Page index 781 is out of bounds for the PDF.
# Warning: Page index 782 is out of bounds for the PDF.
# Warning: Page index 783 is out of bounds for the PDF.
# Warning: Page index 784 is out of bounds for the PDF.
# Warning: Page index 785 is out of bounds for the PDF.
# Warning: Page index 786 is out of bounds for the PDF.
# Warning: Page index 787 is out of bounds for the PDF.
# Warning: Page index 788 is out of bounds for the PDF.
# Warning: Page index 789 is out of bounds for the PDF.
# Warning: Page index 790 is out of bounds for the PDF.
# Warning: Page index 791 is out of bounds for the PDF.
# Warning: Page index 792 is out of bounds for the PDF.
# Warning: Page index 793 is out of bounds for the PDF.
# Warning: Page index 794 is out of bounds for the PDF.
# Warning: Page index 795 is out of bounds for the PDF.
# Warning: Page index 796 is out of bounds for the PDF.
# Warning: Page index 797 is out of bounds for the PDF.
# Warning: Page index 798 is out of bounds for the PDF.
# Warning: Page index 799 is out of bounds for the PDF.
# Warning: Page index 800 is out of bounds for the PDF.
# Warning: Page index 801 is out of bounds for the PDF.
# Warning: Page index 802 is out of bounds for the PDF.
# Warning: Page index 803 is out of bounds for the PDF.
# Warning: Page index 804 is out of bounds for the PDF.
# Warning: Page index 805 is out of bounds for the PDF.
# Warning: Page index 806 is out of bounds for the PDF.
# Warning: Page index 807 is out of bounds for the PDF.
# Warning: Page index 808 is out of bounds for the PDF.
# Warning: Page index 809 is out of bounds for the PDF.
# Warning: Page index 810 is out of bounds for the PDF.
# Warning: Page index 811 is out of bounds for the PDF.
# Warning: Page index 812 is out of bounds for the PDF.
# Warning: Page index 813 is out of bounds for the PDF.
# Warning: Page index 814 is out of bounds for the PDF.
# Warning: Page index 815 is out of bounds for the PDF.
# Warning: Page index 816 is out of bounds for the PDF.
# Warning: Page index 817 is out of bounds for the PDF.
# Warning: Page index 818 is out of bounds for the PDF.
# Warning: Page index 819 is out of bounds for the PDF.
# Warning: Page index 820 is out of bounds for the PDF.
# Warning: Page index 821 is out of bounds for the PDF.
# Warning: Page index 822 is out of bounds for the PDF.
# Warning: Page index 823 is out of bounds for the PDF.
# Warning: Page index 824 is out of bounds for the PDF.
# Warning: Page index 825 is out of bounds for the PDF.
# Warning: Page index 826 is out of bounds for the PDF.
# Warning: Page index 827 is out of bounds for the PDF.
# Warning: Page index 828 is out of bounds for the PDF.
# Warning: Page index 829 is out of bounds for the PDF.
# Warning: Page index 830 is out of bounds for the PDF.
# Warning: Page index 831 is out of bounds for the PDF.
# Warning: Page index 832 is out of bounds for the PDF.
# Warning: Page index 833 is out of bounds for the PDF.
# Warning: Page index 834 is out of bounds for the PDF.
# Warning: Page index 835 is out of bounds for the PDF.
# Warning: Page index 836 is out of bounds for the PDF.
# Warning: Page index 837 is out of bounds for the PDF.
# Warning: Page index 838 is out of bounds for the PDF.
# Warning: Page index 839 is out of bounds for the PDF.
# Warning: Page index 840 is out of bounds for the PDF.
# Warning: Page index 841 is out of bounds for the PDF.
# Warning: Page index 842 is out of bounds for the PDF.
# Warning: Page index 843 is out of bounds for the PDF.
# Warning: Page index 844 is out of bounds for the PDF.
# Warning: Page index 845 is out of bounds for the PDF.
# Warning: Page index 846 is out of bounds for the PDF.
# Warning: Page index 847 is out of bounds for the PDF.
# Warning: Page index 848 is out of bounds for the PDF.
# Warning: Page index 849 is out of bounds for the PDF.
# Warning: Page index 850 is out of bounds for the PDF.
# Warning: Page index 851 is out of bounds for the PDF.
# Warning: Page index 852 is out of bounds for the PDF.
# Warning: Page index 853 is out of bounds for the PDF.
# Warning: Page index 854 is out of bounds for the PDF.
# Warning: Page index 855 is out of bounds for the PDF.
# Warning: Page index 856 is out of bounds for the PDF.
# Warning: Page index 857 is out of bounds for the PDF.
# Warning: Page index 858 is out of bounds for the PDF.
# Warning: Page index 859 is out of bounds for the PDF.
# Warning: Page index 860 is out of bounds for the PDF.
# Warning: Page index 861 is out of bounds for the PDF.
# Warning: Page index 862 is out of bounds for the PDF.
# Warning: Page index 863 is out of bounds for the PDF.
# Warning: Page index 864 is out of bounds for the PDF.
# Warning: Page index 865 is out of bounds for the PDF.
# Warning: Page index 866 is out of bounds for the PDF.
# Warning: Page index 867 is out of bounds for the PDF.
# Warning: Page index 868 is out of bounds for the PDF.
# Warning: Page index 869 is out of bounds for the PDF.
# Warning: Page index 870 is out of bounds for the PDF.
# Warning: Page index 871 is out of bounds for the PDF.
# Warning: Page index 872 is out of bounds for the PDF.
# Warning: Page index 873 is out of bounds for the PDF.
# Warning: Page index 874 is out of bounds for the PDF.
# Warning: Page index 875 is out of bounds for the PDF.
# Warning: Page index 876 is out of bounds for the PDF.
# Warning: Page index 877 is out of bounds for the PDF.
# Warning: Page index 878 is out of bounds for the PDF.
# Warning: Page index 879 is out of bounds for the PDF.
# Warning: Page index 880 is out of bounds for the PDF.
# Warning: Page index 881 is out of bounds for the PDF.
# Warning: Page index 882 is out of bounds for the PDF.
# Warning: Page index 883 is out of bounds for the PDF.
# Warning: Page index 884 is out of bounds for the PDF.
# Warning: Page index 885 is out of bounds for the PDF.
# Warning: Page index 886 is out of bounds for the PDF.
# Warning: Page index 887 is out of bounds for the PDF.
# Warning: Page index 888 is out of bounds for the PDF.
# Warning: Page index 889 is out of bounds for the PDF.
# Warning: Page index 890 is out of bounds for the PDF.
# Warning: Page index 891 is out of bounds for the PDF.
# Warning: Page index 892 is out of bounds for the PDF.
# Warning: Page index 893 is out of bounds for the PDF.
# ...
# Warning: Page index 4140 is out of bounds for the PDF.
# Warning: Page index 4141 is out of bounds for the PDF.
# Warning: Page index 4142 is out of bounds for the PDF.
# Warning: Page index 4143 is out of bounds for the PDF.
# Warning: Page index 4144 is out of bounds for the PDF.
# Warning: Page index 4145 is out of bounds for the PDF.
# Warning: Page index 4146 is out of bounds for the PDF.
# Warning: Page index 4147 is out of bounds for the PDF.
# Warning: Page index 4148 is out of bounds for the PDF.
# Warning: Page index 4149 is out of bounds for the PDF.
# Warning: Page index 4150 is out of bounds for the PDF.
# Warning: Page index 4151 is out of bounds for the PDF.
# Warning: Page index 4152 is out of bounds for the PDF.
# Warning: Page index 4153 is out of bounds for the PDF.
# Warning: Page index 4154 is out of bounds for the PDF.
# Warning: Page index 4155 is out of bounds for the PDF.
# Warning: Page index 4156 is out of bounds for the PDF.
# Warning: Page index 4157 is out of bounds for the PDF.
# Warning: Page index 4158 is out of bounds for the PDF.
# Warning: Page index 4159 is out of bounds for the PDF.
# Warning: Page index 4160 is out of bounds for the PDF.
# Warning: Page index 4161 is out of bounds for the PDF.
# Warning: Page index 4162 is out of bounds for the PDF.
# Warning: Page index 4163 is out of bounds for the PDF.
# Warning: Page index 4164 is out of bounds for the PDF.
# Warning: Page index 4165 is out of bounds for the PDF.
# Warning: Page index 4166 is out of bounds for the PDF.
# Warning: Page index 4167 is out of bounds for the PDF.
# Warning: Page index 4168 is out of bounds for the PDF.
# Warning: Page index 4169 is out of bounds for the PDF.
# Warning: Page index 4170 is out of bounds for the PDF.
# Warning: Page index 4171 is out of bounds for the PDF.
# Warning: Page index 4172 is out of bounds for the PDF.
# Warning: Page index 4173 is out of bounds for the PDF.
# Warning: Page index 4174 is out of bounds for the PDF.
# Warning: Page index 4175 is out of bounds for the PDF.
# Warning: Page index 4176 is out of bounds for the PDF.
# Warning: Page index 4177 is out of bounds for the PDF.
# Warning: Page index 4178 is out of bounds for the PDF.
# Warning: Page index 4179 is out of bounds for the PDF.
# Warning: Page index 4180 is out of bounds for the PDF.
# Warning: Page index 4181 is out of bounds for the PDF.
# Warning: Page index 4182 is out of bounds for the PDF.
# Warning: Page index 4183 is out of bounds for the PDF.
# Warning: Page index 4184 is out of bounds for the PDF.
# Warning: Page index 4185 is out of bounds for the PDF.
# Warning: Page index 4186 is out of bounds for the PDF.
# Warning: Page index 4187 is out of bounds for the PDF.
# Warning: Page index 4188 is out of bounds for the PDF.
# Warning: Page index 4189 is out of bounds for the PDF.
# Warning: Page index 4190 is out of bounds for the PDF.
# Warning: Page index 4191 is out of bounds for the PDF.
# Warning: Page index 4192 is out of bounds for the PDF.
# Warning: Page index 4193 is out of bounds for the PDF.
# Warning: Page index 4194 is out of bounds for the PDF.
# Warning: Page index 4195 is out of bounds for the PDF.
# Warning: Page index 4196 is out of bounds for the PDF.
# Warning: Page index 4197 is out of bounds for the PDF.
# Warning: Page index 4198 is out of bounds for the PDF.
# Warning: Page index 4199 is out of bounds for the PDF.
# Warning: Page index 4200 is out of bounds for the PDF.
# Warning: Page index 4201 is out of bounds for the PDF.
# Warning: Page index 4202 is out of bounds for the PDF.
# Warning: Page index 4203 is out of bounds for the PDF.
# Warning: Page index 4204 is out of bounds for the PDF.
# Warning: Page index 4205 is out of bounds for the PDF.
# Warning: Page index 4206 is out of bounds for the PDF.
# Warning: Page index 4207 is out of bounds for the PDF.
# Warning: Page index 4208 is out of bounds for the PDF.
# Warning: Page index 4209 is out of bounds for the PDF.
# Warning: Page index 4210 is out of bounds for the PDF.
# Warning: Page index 4211 is out of bounds for the PDF.
# Warning: Page index 4212 is out of bounds for the PDF.
# Warning: Page index 4213 is out of bounds for the PDF.
# Warning: Page index 4214 is out of bounds for the PDF.
# Warning: Page index 4215 is out of bounds for the PDF.
# Warning: Page index 4216 is out of bounds for the PDF.
# Warning: Page index 4217 is out of bounds for the PDF.
# Warning: Page index 4218 is out of bounds for the PDF.
# Warning: Page index 4219 is out of bounds for the PDF.
# Warning: Page index 4220 is out of bounds for the PDF.
# Warning: Page index 4221 is out of bounds for the PDF.
# Warning: Page index 4222 is out of bounds for the PDF.
# Warning: Page index 4223 is out of bounds for the PDF.
# Warning: Page index 4224 is out of bounds for the PDF.
# Warning: Page index 4225 is out of bounds for the PDF.
# Warning: Page index 4226 is out of bounds for the PDF.
# Warning: Page index 4227 is out of bounds for the PDF.
# Warning: Page index 4228 is out of bounds for the PDF.
# Warning: Page index 4229 is out of bounds for the PDF.
# Warning: Page index 4230 is out of bounds for the PDF.
# Warning: Page index 4231 is out of bounds for the PDF.
# Warning: Page index 4232 is out of bounds for the PDF.
# Warning: Page index 4233 is out of bounds for the PDF.
# Warning: Page index 4234 is out of bounds for the PDF.
# Warning: Page index 4235 is out of bounds for the PDF.
# Warning: Page index 4236 is out of bounds for the PDF.
# Warning: Page index 4237 is out of bounds for the PDF.
# Warning: Page index 4238 is out of bounds for the PDF.
# Warning: Page index 4239 is out of bounds for the PDF.
# Warning: Page index 4240 is out of bounds for the PDF.
# Warning: Page index 4241 is out of bounds for the PDF.
# Warning: Page index 4242 is out of bounds for the PDF.
# Warning: Page index 4243 is out of bounds for the PDF.
# Warning: Page index 4244 is out of bounds for the PDF.
# Warning: Page index 4245 is out of bounds for the PDF.
# Warning: Page index 4246 is out of bounds for the PDF.
# Warning: Page index 4247 is out of bounds for the PDF.
# Warning: Page index 4248 is out of bounds for the PDF.
# Warning: Page index 4249 is out of bounds for the PDF.
# Warning: Page index 4250 is out of bounds for the PDF.
# Warning: Page index 4251 is out of bounds for the PDF.
# Warning: Page index 4252 is out of bounds for the PDF.
# Warning: Page index 4253 is out of bounds for the PDF.
# Warning: Page index 4254 is out of bounds for the PDF.
# Warning: Page index 4255 is out of bounds for the PDF.
# Warning: Page index 4256 is out of bounds for the PDF.
# Warning: Page index 4257 is out of bounds for the PDF.
# Warning: Page index 4258 is out of bounds for the PDF.
# Warning: Page index 4259 is out of bounds for the PDF.
# Warning: Page index 4260 is out of bounds for the PDF.
# Warning: Page index 4261 is out of bounds for the PDF.
# Warning: Page index 4262 is out of bounds for the PDF.
# Warning: Page index 4263 is out of bounds for the PDF.
# Warning: Page index 4264 is out of bounds for the PDF.
# Warning: Page index 4265 is out of bounds for the PDF.
# Warning: Page index 4266 is out of bounds for the PDF.
# Warning: Page index 4267 is out of bounds for the PDF.
# Warning: Page index 4268 is out of bounds for the PDF.
# Warning: Page index 4269 is out of bounds for the PDF.
# Warning: Page index 4270 is out of bounds for the PDF.
# Warning: Page index 4271 is out of bounds for the PDF.
# Warning: Page index 4272 is out of bounds for the PDF.
# Warning: Page index 4273 is out of bounds for the PDF.
# Warning: Page index 4274 is out of bounds for the PDF.
# Warning: Page index 4275 is out of bounds for the PDF.
# Warning: Page index 4276 is out of bounds for the PDF.
# Warning: Page index 4277 is out of bounds for the PDF.
# Warning: Page index 4278 is out of bounds for the PDF.
# Warning: Page index 4279 is out of bounds for the PDF.
# Warning: Page index 4280 is out of bounds for the PDF.
# Warning: Page index 4281 is out of bounds for the PDF.
# Warning: Page index 4282 is out of bounds for the PDF.
# Warning: Page index 4283 is out of bounds for the PDF.
# Warning: Page index 4284 is out of bounds for the PDF.
# Warning: Page index 4285 is out of bounds for the PDF.
# Warning: Page index 4286 is out of bounds for the PDF.
# Warning: Page index 4287 is out of bounds for the PDF.
# Warning: Page index 4288 is out of bounds for the PDF.
# Warning: Page index 4289 is out of bounds for the PDF.
# Warning: Page index 4290 is out of bounds for the PDF.
# Warning: Page index 4291 is out of bounds for the PDF.
# Warning: Page index 4292 is out of bounds for the PDF.
# Warning: Page index 4293 is out of bounds for the PDF.
# Warning: Page index 4294 is out of bounds for the PDF.
# Warning: Page index 4295 is out of bounds for the PDF.
# Warning: Page index 4296 is out of bounds for the PDF.
# Warning: Page index 4297 is out of bounds for the PDF.
# Warning: Page index 4298 is out of bounds for the PDF.
# Warning: Page index 4299 is out of bounds for the PDF.
# Warning: Page index 4300 is out of bounds for the PDF.
# Warning: Page index 4301 is out of bounds for the PDF.
# Warning: Page index 4302 is out of bounds for the PDF.
# Warning: Page index 4303 is out of bounds for the PDF.
# Warning: Page index 4304 is out of bounds for the PDF.
# Warning: Page index 4305 is out of bounds for the PDF.
# Warning: Page index 4306 is out of bounds for the PDF.
# Warning: Page index 4307 is out of bounds for the PDF.
# Warning: Page index 4308 is out of bounds for the PDF.
# Warning: Page index 4309 is out of bounds for the PDF.
# Warning: Page index 4310 is out of bounds for the PDF.
# Warning: Page index 4311 is out of bounds for the PDF.
# Warning: Page index 4312 is out of bounds for the PDF.
# Warning: Page index 4313 is out of bounds for the PDF.
# Warning: Page index 4314 is out of bounds for the PDF.
# Warning: Page index 4315 is out of bounds for the PDF.
# Warning: Page index 4316 is out of bounds for the PDF.
# Warning: Page index 4317 is out of bounds for the PDF.
# Warning: Page index 4318 is out of bounds for the PDF.
# Warning: Page index 4319 is out of bounds for the PDF.
# Warning: Page index 4320 is out of bounds for the PDF.
# Warning: Page index 4321 is out of bounds for the PDF.
# Warning: Page index 4322 is out of bounds for the PDF.
# Warning: Page index 4323 is out of bounds for the PDF.
# Warning: Page index 4324 is out of bounds for the PDF.
# Warning: Page index 4325 is out of bounds for the PDF.
# Warning: Page index 4326 is out of bounds for the PDF.
# Warning: Page index 4327 is out of bounds for the PDF.
# Warning: Page index 4328 is out of bounds for the PDF.
# Warning: Page index 4329 is out of bounds for the PDF.
# Warning: Page index 4330 is out of bounds for the PDF.
# Warning: Page index 4331 is out of bounds for the PDF.
# Warning: Page index 4332 is out of bounds for the PDF.
# Warning: Page index 4333 is out of bounds for the PDF.
# Warning: Page index 4334 is out of bounds for the PDF.
# Warning: Page index 4335 is out of bounds for the PDF.
# Warning: Page index 4336 is out of bounds for the PDF.
# Warning: Page index 4337 is out of bounds for the PDF.
# Warning: Page index 4338 is out of bounds for the PDF.
# Warning: Page index 4339 is out of bounds for the PDF.
# Warning: Page index 4340 is out of bounds for the PDF.
# Warning: Page index 4341 is out of bounds for the PDF.
# Warning: Page index 4342 is out of bounds for the PDF.
# Warning: Page index 4343 is out of bounds for the PDF.
# Warning: Page index 4344 is out of bounds for the PDF.
# Warning: Page index 4345 is out of bounds for the PDF.
# Warning: Page index 4346 is out of bounds for the PDF.
# Warning: Page index 4347 is out of bounds for the PDF.
# Warning: Page index 4348 is out of bounds for the PDF.
# Warning: Page index 4349 is out of bounds for the PDF.
# Warning: Page index 4350 is out of bounds for the PDF.
# Warning: Page index 4351 is out of bounds for the PDF.
# Warning: Page index 4352 is out of bounds for the PDF.
# Warning: Page index 4353 is out of bounds for the PDF.
# Warning: Page index 4354 is out of bounds for the PDF.
# Warning: Page index 4355 is out of bounds for the PDF.
# Warning: Page index 4356 is out of bounds for the PDF.
# Warning: Page index 4357 is out of bounds for the PDF.
# Warning: Page index 4358 is out of bounds for the PDF.
# Warning: Page index 4359 is out of bounds for the PDF.
# Warning: Page index 4360 is out of bounds for the PDF.
# Warning: Page index 4361 is out of bounds for the PDF.
# Warning: Page index 4362 is out of bounds for the PDF.
# Warning: Page index 4363 is out of bounds for the PDF.
# Warning: Page index 4364 is out of bounds for the PDF.
# Warning: Page index 4365 is out of bounds for the PDF.
# Warning: Page index 4366 is out of bounds for the PDF.
# Warning: Page index 4367 is out of bounds for the PDF.
# Warning: Page index 4368 is out of bounds for the PDF.
# Warning: Page index 4369 is out of bounds for the PDF.
# Warning: Page index 4370 is out of bounds for the PDF.
# Warning: Page index 4371 is out of bounds for the PDF.
# Warning: Page index 4372 is out of bounds for the PDF.
# Warning: Page index 4373 is out of bounds for the PDF.
# Warning: Page index 4374 is out of bounds for the PDF.
# Warning: Page index 4375 is out of bounds for the PDF.
# Warning: Page index 4376 is out of bounds for the PDF.
# Warning: Page index 4377 is out of bounds for the PDF.
# Warning: Page index 4378 is out of bounds for the PDF.
# Warning: Page index 4379 is out of bounds for the PDF.
# Warning: Page index 4380 is out of bounds for the PDF.
# Warning: Page index 4381 is out of bounds for the PDF.
# Warning: Page index 4382 is out of bounds for the PDF.
# Warning: Page index 4383 is out of bounds for the PDF.
# Warning: Page index 4384 is out of bounds for the PDF.
# Warning: Page index 4385 is out of bounds for the PDF.
# Warning: Page index 4386 is out of bounds for the PDF.
# Warning: Page index 4387 is out of bounds for the PDF.
# Warning: Page index 4388 is out of bounds for the PDF.
# Warning: Page index 4389 is out of bounds for the PDF.
# Warning: Page index 4390 is out of bounds for the PDF.
# Warning: Page index 4391 is out of bounds for the PDF.
# Warning: Page index 4392 is out of bounds for the PDF.
# Warning: Page index 4393 is out of bounds for the PDF.
# Warning: Page index 4394 is out of bounds for the PDF.
# Warning: Page index 4395 is out of bounds for the PDF.
# Warning: Page index 4396 is out of bounds for the PDF.
# Warning: Page index 4397 is out of bounds for the PDF.
# Warning: Page index 4398 is out of bounds for the PDF.
# Warning: Page index 4399 is out of bounds for the PDF.
# Warning: Page index 4400 is out of bounds for the PDF.
# Warning: Page index 4401 is out of bounds for the PDF.
# Warning: Page index 4402 is out of bounds for the PDF.
# Warning: Page index 4403 is out of bounds for the PDF.
# Warning: Page index 4404 is out of bounds for the PDF.
# Warning: Page index 4405 is out of bounds for the PDF.
# Warning: Page index 4406 is out of bounds for the PDF.
# Warning: Page index 4407 is out of bounds for the PDF.
# Warning: Page index 4408 is out of bounds for the PDF.
# Warning: Page index 4409 is out of bounds for the PDF.
# Warning: Page index 4410 is out of bounds for the PDF.
# Warning: Page index 4411 is out of bounds for the PDF.
# Warning: Page index 4412 is out of bounds for the PDF.
# Warning: Page index 4413 is out of bounds for the PDF.
# Warning: Page index 4414 is out of bounds for the PDF.
# Warning: Page index 4415 is out of bounds for the PDF.
# Warning: Page index 4416 is out of bounds for the PDF.
# Warning: Page index 4417 is out of bounds for the PDF.
# Warning: Page index 4418 is out of bounds for the PDF.
# Warning: Page index 4419 is out of bounds for the PDF.
# Warning: Page index 4420 is out of bounds for the PDF.
# Warning: Page index 4421 is out of bounds for the PDF.
# Warning: Page index 4422 is out of bounds for the PDF.
# Warning: Page index 4423 is out of bounds for the PDF.
# Warning: Page index 4424 is out of bounds for the PDF.
# Warning: Page index 4425 is out of bounds for the PDF.
# Warning: Page index 4426 is out of bounds for the PDF.
# Warning: Page index 4427 is out of bounds for the PDF.
# Warning: Page index 4428 is out of bounds for the PDF.
# Warning: Page index 4429 is out of bounds for the PDF.

# %%
import re

# %%
# --- Configuration ---
# Columns for the final CSV
TARGET_COLUMN_HEADERS = [
    "Page Number",
    "Heading/Subheading",
    "Stat. Suffix",
    "Article Description",
    "Unit of Quantity",
    "Rates of Duty - General",
    "Rates of Duty - Special",
    "Rates of Duty - 2"
]

# Keywords to identify a HTS-like table header (lowercase for case-insensitive matching)
# These are crucial for identifying the tables of interest.
HTS_HEADER_KEYWORDS = [
    "heading/subheading", "heading/", "subheading", "stat.", "suf", "suffix",
    "article description", "article", "description",
    "unit of quantity", "unit", "quantity",
    "rates of duty", "rates", "duty", "general", "special"
]
MIN_HTS_HEADER_KEYWORDS_MATCH = 3 # Min distinct keywords from the list above to be found in a potential header row
MIN_COLUMNS_FOR_HTS_TABLE = 5   # A HTS table should have at least this many columns

# --- Helper Functions ---
def clean_text(text):
    """Cleans cell text: replaces None with '', strips whitespace, replaces newlines."""
    if text is None:
        return ""
    return str(text).replace('\n', ' ').strip()

def remove_footnote_markers(text):
    """Removes footnote markers like 1/, 2/ etc. from text."""
    if text is None:
        return ""
    return re.sub(r'\s*\d+/\s*', '', str(text)).strip()

def is_potential_hts_header_row(row_cells, keywords_list, min_matches):
    """
    Checks if a list of cell texts (a row) likely constitutes an HTS table header.
    """
    if not row_cells:
        return False
    
    match_count = 0
    # Combine all cell text in the row to check for keywords
    combined_text = " ".join(filter(None, [str(c).lower() for c in row_cells]))
    
    for keyword in keywords_list:
        if keyword in combined_text:
            match_count += 1
            
    return match_count >= min_matches

def map_extracted_row_to_target(raw_row_cells, page_num):
    """
    Maps the cells of an extracted raw_row to the TARGET_COLUMN_HEADERS structure.
    This is a heuristic-based mapping assuming HTS structure.
    It expects raw_row_cells to contain the data portion of the table.
    """
    mapped_data = {header: "" for header in TARGET_COLUMN_HEADERS}
    mapped_data["Page Number"] = page_num

    num_raw_cells = len(raw_row_cells)

    if num_raw_cells > 0:
        mapped_data["Heading/Subheading"] = remove_footnote_markers(clean_text(raw_row_cells[0]))
    if num_raw_cells > 1:
        mapped_data["Stat. Suffix"] = remove_footnote_markers(clean_text(raw_row_cells[1]))
    if num_raw_cells > 2:
        # Article Description can sometimes be split by pdfplumber or span visually
        # If fewer columns are detected than expected, later columns might be part of Article Description
        # For simplicity now, direct map. Robust solution would check number of cols vs expected.
        mapped_data["Article Description"] = remove_footnote_markers(clean_text(raw_row_cells[2]))
    if num_raw_cells > 3:
        mapped_data["Unit of Quantity"] = remove_footnote_markers(clean_text(raw_row_cells[3]))
    if num_raw_cells > 4:
        mapped_data["Rates of Duty - General"] = remove_footnote_markers(clean_text(raw_row_cells[4]))
    if num_raw_cells > 5:
        mapped_data["Rates of Duty - Special"] = remove_footnote_markers(clean_text(raw_row_cells[5]))
    if num_raw_cells > 6:
        mapped_data["Rates of Duty - 2"] = remove_footnote_markers(clean_text(raw_row_cells[6]))
    
    # If more cells exist, they are currently ignored. Could append to Article Description or a misc column.
    
    return mapped_data

def process_pdf_for_hts_tables(pdf_path):
    """
    Processes the entire PDF, identifies HTS tables, extracts data, and returns a DataFrame.
    """
    all_hts_rows_data = []
    
    # Global context for HTS codes (simplified)
    current_main_heading_context = ""
    current_subheading_base_context = ""

    if not os.path.exists(pdf_path):
        print(f"Error: PDF file not found at '{pdf_path}'")
        return pd.DataFrame()

    try:
        with pdfplumber.open(pdf_path) as pdf:
            total_pages = len(pdf.pages)
            print(f"Starting processing of '{os.path.basename(pdf_path)}' ({total_pages} pages)...")

            for i, page in enumerate(pdf.pages):
                page_num = i + 1
                if page_num % 100 == 0 or page_num == 1 or page_num == total_pages:
                    print(f"  Processing page {page_num}/{total_pages}...")

                try:
                    # Attempt to extract tables using strict line detection first
                    tables = page.extract_tables(table_settings={
                        "vertical_strategy": "lines_strict",
                        "horizontal_strategy": "lines_strict",
                        "snap_tolerance": 5, # Increased tolerance
                        "join_tolerance": 5,
                    })
                    if not tables: # Fallback to text-based if no lines found
                         tables = page.extract_tables(table_settings={
                            "vertical_strategy": "text",
                            "horizontal_strategy": "text",
                             "text_x_tolerance": 3,
                             "text_y_tolerance": 3,
                             "snap_tolerance": 5,
                             "join_tolerance": 5,
                        })
                except Exception as e:
                    # print(f"    Warning: Could not extract tables from page {page_num}. Error: {e}")
                    tables = [] # Ensure tables is an empty list to avoid further errors

                if not tables:
                    continue

                for table_idx, extracted_table in enumerate(tables):
                    if not extracted_table or len(extracted_table) < 2: # Need at least a header and one data row
                        continue
                    
                    # Check table width
                    if len(extracted_table[0]) < MIN_COLUMNS_FOR_HTS_TABLE:
                        continue

                    # Identify if this table is an HTS table by checking its first few rows for keywords
                    header_row_index = -1
                    for r_idx, row_content in enumerate(extracted_table[:3]): # Check first 3 rows
                        cleaned_row_cells = [clean_text(cell) for cell in row_content]
                        if is_potential_hts_header_row(cleaned_row_cells, HTS_HEADER_KEYWORDS, MIN_HTS_HEADER_KEYWORDS_MATCH):
                            header_row_index = r_idx
                            break
                    
                    if header_row_index == -1: # Not identified as an HTS table
                        continue

                    # If identified, process rows from (header_row_index + 1) onwards
                    for data_row_idx in range(header_row_index + 1, len(extracted_table)):
                        raw_data_cells = extracted_table[data_row_idx]
                        
                        # Basic validation: ensure it's not an empty or malformed row
                        if not any(raw_data_cells) or not any(clean_text(c) for c in raw_data_cells):
                            continue
                        
                        mapped_row = map_extracted_row_to_target(raw_data_cells, page_num)

                        # --- HTS Specific Context Logic (Simplified) ---
                        hs_text = mapped_row["Heading/Subheading"]
                        stat_suffix = mapped_row["Stat. Suffix"]
                        article_desc = mapped_row["Article Description"]
                        
                        full_subheading = ""
                        # Try to parse and maintain current HTS code context
                        if re.match(r'^\d{4}\.\d{2}\.\d{2}$', hs_text): # Full HTS e.g., 0101.21.00
                            full_subheading = hs_text
                            current_main_heading_context = hs_text[:4]
                            current_subheading_base_context = hs_text
                        elif re.match(r'^\d{4}(\s*\(con\.\))?$', hs_text): # Main heading e.g., 0101 or 0101 (con.)
                            potential_main = hs_text.replace('(con.)','').strip()
                            if re.match(r'^\d{4}$', potential_main):
                                current_main_heading_context = potential_main
                            full_subheading = current_main_heading_context # Use main as placeholder
                            # If it's a "(con.)" line for a main heading and article desc is empty, it's usually just a spacer
                        elif hs_text: # Other non-empty heading text
                            # Could be a partial like ".29.00" or just descriptive text if first col isn't code
                            if current_main_heading_context and re.match(r'^\s*\.\d{2}\.\d{2}$', hs_text.replace(current_main_heading_context, '', 1).strip()):
                                full_subheading = current_main_heading_context + hs_text.replace(current_main_heading_context, '', 1).strip()
                                current_subheading_base_context = full_subheading
                            else:
                                full_subheading = hs_text # Keep as is if can't resolve
                        
                        # If stat_suffix exists, the full_subheading should be the base HTS code
                        if not full_subheading and stat_suffix and current_subheading_base_context:
                            full_subheading = current_subheading_base_context
                        elif not full_subheading and current_main_heading_context: # Default if nothing else
                            full_subheading = current_main_heading_context
                        
                        mapped_row["Heading/Subheading"] = full_subheading
                        # --- End HTS Specific Context Logic ---

                        # Add row if it has some substance beyond just page number or context codes
                        if any([mapped_row["Stat. Suffix"], 
                                mapped_row["Article Description"], 
                                mapped_row["Unit of Quantity"],
                                mapped_row["Rates of Duty - General"]]):
                            all_hts_rows_data.append(mapped_row)
            
            print(f"  Finished processing all pages.")

    except Exception as e:
        print(f"An error occurred during PDF processing: {e}")
        return pd.DataFrame(all_hts_rows_data, columns=TARGET_COLUMN_HEADERS) # Return what we have so far

    if not all_hts_rows_data:
        print("No HTS-like tables meeting the criteria were found in the document.")
        return pd.DataFrame()

    df = pd.DataFrame(all_hts_rows_data, columns=TARGET_COLUMN_HEADERS)
    
    # Final cleanup of DataFrame
    # Drop rows where essential HTS data fields are all empty
    essential_cols = ["Heading/Subheading", "Stat. Suffix", "Article Description", 
                      "Unit of Quantity", "Rates of Duty - General"]
    df.dropna(how='all', subset=essential_cols, inplace=True)
    
    # Remove rows that might just be section headers or empty context propagations
    df = df[~((df['Stat. Suffix'] == '') & \
              (df['Article Description'] == '') & \
              (df['Unit of Quantity'] == '') & \
              (df['Rates of Duty - General'] == '') & \
              (df['Rates of Duty - Special'] == '') & \
              (df['Rates of Duty - 2'] == '')
             )]

    return df

# %%
fullpdf = "../data/raw/Chapter 1.pdf"
output_csv_file = "../data/processed/fullhts_extracted_data.csv"

final_df = process_pdf_for_hts_tables(fullpdf)

if not final_df.empty:
    try:
        final_df.to_csv(output_csv_file, index=False, encoding='utf-8')
        print(f"\nSuccessfully extracted {len(final_df)} HTS data rows.")
        print(f"Data saved to '{output_csv_file}'")
        print("\nExtracted data shape:")
        print(final_df.shape)
    except Exception as e:
        print(f"\nError saving data to CSV: {e}")
else:
    print("\nNo data was extracted or data was empty after cleanup.")
# Out:
# Starting processing of 'Chapter 1.pdf' (10 pages)...
#   Processing page 1/10...
#   Processing page 10/10...
#   Finished processing all pages.
#
# Successfully extracted 208 HTS data rows.
# Data saved to '../data/processed/fullhts_extracted_data.csv'
#
# Extracted data shape:
# (208, 8)

# %%
output_csv_file = "../data/processed/fullhts_extracted_data.csv"

df = pd.read_csv(output_csv_file)

# %%
import os

# %%
df.shape, df.isna().sum()
# Out:
# ((208, 8),
#  Page Number                  0
#  Heading/Subheading           1
#  Stat. Suffix               105
#  Article Description         62
#  Unit of Quantity            67
#  Rates of Duty - General    153
#  Rates of Duty - Special    172
#  Rates of Duty - 2          184
#  dtype: int64)

# %%
# df.style

# %%
import pdfplumber
import re
import os
import sqlite3 # For SQLite database interaction
import time    # For progress and timing

# --- Configuration (same as before) ---
DB_NAME = "../data/processed/hts_schedule_data.db"
TABLE_NAME = "hts_entries"

# Columns for the database table and expected data order
# IMPORTANT: The order here must match the order of values when inserting
DB_COLUMN_DEFINITIONS = [
    ("Page_Number", "INTEGER"), # Using underscores for DB friendliness
    ("Heading_Subheading", "TEXT"),
    ("Stat_Suffix", "TEXT"),
    ("Article_Description", "TEXT"),
    ("Unit_of_Quantity", "TEXT"),
    ("Rates_of_Duty_General", "TEXT"),
    ("Rates_of_Duty_Special", "TEXT"),
    ("Rates_of_Duty_2", "TEXT")
]
# For DictWriter-like mapping from processed data (keys should match map_extracted_row_to_target output)
MAPPED_DATA_KEYS = [
    "Page Number", # These keys are from map_extracted_row_to_target
    "Heading/Subheading",
    "Stat. Suffix",
    "Article Description",
    "Unit of Quantity",
    "Rates of Duty - General",
    "Rates of Duty - Special",
    "Rates of Duty - 2"
]


HTS_HEADER_KEYWORDS = [
    "heading/subheading", "heading/", "subheading", "stat.", "suf", "suffix",
    "article description", "article", "description",
    "unit of quantity", "unit", "quantity",
    "rates of duty", "rates", "duty", "general", "special"
]
MIN_HTS_HEADER_KEYWORDS_MATCH = 3
MIN_COLUMNS_FOR_HTS_TABLE = 5

# --- Helper Functions (clean_text, remove_footnote_markers, is_potential_hts_header_row - same as before) ---
def clean_text(text):
    if text is None: return ""
    return str(text).replace('\n', ' ').strip()

def remove_footnote_markers(text):
    if text is None: return ""
    return re.sub(r'\s*\d+/\s*', '', str(text)).strip()

def is_potential_hts_header_row(row_cells, keywords_list, min_matches):
    if not row_cells: return False
    combined_text = " ".join(filter(None, [str(c).lower() for c in row_cells]))
    match_count = 0
    for keyword in keywords_list:
        if keyword in combined_text:
            match_count += 1
    return match_count >= min_matches

def map_extracted_row_to_target_dict(raw_row_cells, page_num):
    """
    Maps raw cells to a dictionary with predefined keys (MAPPED_DATA_KEYS).
    This output dictionary's keys will be used for database insertion.
    """
    mapped_data = {key: "" for key in MAPPED_DATA_KEYS} # Initialize with all keys
    mapped_data["Page Number"] = page_num # Key from MAPPED_DATA_KEYS
    
    num_raw_cells = len(raw_row_cells)
    
    if num_raw_cells > 0: mapped_data["Heading/Subheading"] = remove_footnote_markers(clean_text(raw_row_cells[0]))
    if num_raw_cells > 1: mapped_data["Stat. Suffix"] = remove_footnote_markers(clean_text(raw_row_cells[1]))
    if num_raw_cells > 2: mapped_data["Article Description"] = remove_footnote_markers(clean_text(raw_row_cells[2]))
    if num_raw_cells > 3: mapped_data["Unit of Quantity"] = remove_footnote_markers(clean_text(raw_row_cells[3]))
    if num_raw_cells > 4: mapped_data["Rates of Duty - General"] = remove_footnote_markers(clean_text(raw_row_cells[4]))
    if num_raw_cells > 5: mapped_data["Rates of Duty - Special"] = remove_footnote_markers(clean_text(raw_row_cells[5]))
    if num_raw_cells > 6: mapped_data["Rates of Duty - 2"] = remove_footnote_markers(clean_text(raw_row_cells[6]))
    return mapped_data


def setup_database(db_name, table_name, column_definitions):
    """Creates the SQLite database and table if they don't exist."""
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    
    # Create column definition string for CREATE TABLE statement
    cols_def_str = ", ".join([f'"{col_name}" {col_type}' for col_name, col_type in column_definitions])
    
    # Check if table exists
    cursor.execute(f"SELECT name FROM sqlite_master WHERE type='table' AND name='{table_name}';")
    if cursor.fetchone():
        print(f"Table '{table_name}' already exists. Appending data or consider deleting the DB file first if a fresh start is needed.")
    else:
        cursor.execute(f'''
            CREATE TABLE {table_name} (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                {cols_def_str}
            )
        ''')
        print(f"Table '{table_name}' created in database '{db_name}'.")
    conn.commit()
    return conn, cursor

def insert_row_into_db(cursor, table_name, column_names_for_insert, data_dict):
    """Inserts a single row (as a dictionary) into the database."""
    # Ensure values are in the correct order corresponding to column_names_for_insert
    values_to_insert = [data_dict.get(key_from_mapped_data, "") for key_from_mapped_data in MAPPED_DATA_KEYS]
    
    placeholders = ', '.join(['?'] * len(column_names_for_insert))
    # column_names_for_insert are the actual DB column names (e.g., "Page_Number")
    cols_sql_str = ', '.join([f'"{col}"' for col in column_names_for_insert])

    sql = f"INSERT INTO {table_name} ({cols_sql_str}) VALUES ({placeholders})"
    cursor.execute(sql, values_to_insert)


def process_pdf_and_write_to_db(pdf_path, db_conn, db_cursor):
    """
    Processes PDF, identifies HTS tables, and writes data incrementally to SQLite.
    Returns the total number of rows written.
    """
    rows_written_count = 0
    
    current_main_heading_context = ""
    current_subheading_base_context = ""
    
    db_column_names = [col_def[0] for col_def in DB_COLUMN_DEFINITIONS] # e.g., ["Page_Number", "Heading_Subheading", ...]

    if not os.path.exists(pdf_path):
        print(f"Error: PDF file not found at '{pdf_path}'")
        return 0

    try:
        with pdfplumber.open(pdf_path) as pdf:
            total_pages = len(pdf.pages)
            print(f"Starting processing of '{os.path.basename(pdf_path)}' ({total_pages} pages)...")
            print(f"Data will be written incrementally to SQLite table '{TABLE_NAME}' in '{DB_NAME}'")
            start_time = time.time()

            for i, page in enumerate(pdf.pages):
                page_num = i + 1
                if page_num % 50 == 0 or page_num == 1 or page_num == total_pages:
                    elapsed_time = time.time() - start_time
                    print(f"  Processing page {page_num}/{total_pages}... (Elapsed: {elapsed_time:.2f}s)")

                page_rows_data = [] # Temporary list for rows from the current page

                try:
                    tables = page.extract_tables(table_settings={
                        "vertical_strategy": "lines_strict", "horizontal_strategy": "lines_strict",
                        "snap_tolerance": 5, "join_tolerance": 5,
                    })
                    if not tables:
                        tables = page.extract_tables(table_settings={
                            "vertical_strategy": "text", "horizontal_strategy": "text",
                            "text_x_tolerance": 3, "text_y_tolerance": 3,
                            "snap_tolerance": 5, "join_tolerance": 5,
                        })
                except Exception:
                    tables = []

                if not tables:
                    continue

                for extracted_table in tables:
                    if not extracted_table or len(extracted_table) < 2 or len(extracted_table[0]) < MIN_COLUMNS_FOR_HTS_TABLE:
                        continue

                    header_row_index = -1
                    for r_idx, row_content in enumerate(extracted_table[:3]):
                        cleaned_row_cells = [clean_text(cell) for cell in row_content]
                        if is_potential_hts_header_row(cleaned_row_cells, HTS_HEADER_KEYWORDS, MIN_HTS_HEADER_KEYWORDS_MATCH):
                            header_row_index = r_idx
                            break
                    
                    if header_row_index == -1:
                        continue

                    for data_row_idx in range(header_row_index + 1, len(extracted_table)):
                        raw_data_cells = extracted_table[data_row_idx]
                        if not any(raw_data_cells) or not any(clean_text(c) for c in raw_data_cells):
                            continue
                        
                        mapped_row_dict = map_extracted_row_to_target_dict(raw_data_cells, page_num)

                        # --- HTS Specific Context Logic (Simplified - same as before) ---
                        hs_text = mapped_row_dict["Heading/Subheading"]
                        full_subheading = ""
                        if re.match(r'^\d{4}\.\d{2}\.\d{2}$', hs_text):
                            full_subheading = hs_text
                            current_main_heading_context = hs_text[:4]
                            current_subheading_base_context = hs_text
                        elif re.match(r'^\d{4}(\s*\(con\.\))?$', hs_text):
                            potential_main = hs_text.replace('(con.)','').strip()
                            if re.match(r'^\d{4}$', potential_main):
                                current_main_heading_context = potential_main
                            full_subheading = current_main_heading_context
                        elif hs_text:
                            if current_main_heading_context and re.match(r'^\s*\.\d{2}\.\d{2}$', hs_text.replace(current_main_heading_context, '', 1).strip()):
                                full_subheading = current_main_heading_context + hs_text.replace(current_main_heading_context, '', 1).strip()
                                current_subheading_base_context = full_subheading
                            else:
                                full_subheading = hs_text
                        
                        if not full_subheading and mapped_row_dict["Stat. Suffix"] and current_subheading_base_context:
                            full_subheading = current_subheading_base_context
                        elif not full_subheading and current_main_heading_context:
                            full_subheading = current_main_heading_context
                        
                        mapped_row_dict["Heading/Subheading"] = full_subheading
                        # --- End HTS Specific Context Logic ---
                        
                        essential_cols_check = [mapped_row_dict["Stat. Suffix"], 
                                       mapped_row_dict["Article Description"], 
                                       mapped_row_dict["Unit of Quantity"],
                                       mapped_row_dict["Rates of Duty - General"]]
                        
                        if any(essential_cols_check):
                            page_rows_data.append(mapped_row_dict)
                
                # Batch insert rows from the current page
                if page_rows_data:
                    for row_dict in page_rows_data:
                         insert_row_into_db(db_cursor, TABLE_NAME, db_column_names, row_dict)
                    rows_written_count += len(page_rows_data)
                    db_conn.commit() # Commit after processing each page's data

            total_time = time.time() - start_time
            print(f"  Finished processing all pages. Total time: {total_time:.2f}s")

    except Exception as e:
        print(f"An error occurred during PDF processing or DB writing: {e}")
        db_conn.rollback() # Rollback any uncommitted changes if error
    
    return rows_written_count

# %%
import pdfplumber
import re
import os
import sqlite3 # For SQLite database interaction
import time    # For progress and timing

# --- Configuration (same as before) ---
DB_NAME = "../data/processed/fill_hts_schedule_data.db"
TABLE_NAME = "hts_entries"

# Columns for the database table and expected data order
# IMPORTANT: The order here must match the order of values when inserting
DB_COLUMN_DEFINITIONS = [
    ("Page_Number", "INTEGER"), # Using underscores for DB friendliness
    ("Heading_Subheading", "TEXT"),
    ("Stat_Suffix", "TEXT"),
    ("Article_Description", "TEXT"),
    ("Unit_of_Quantity", "TEXT"),
    ("Rates_of_Duty_General", "TEXT"),
    ("Rates_of_Duty_Special", "TEXT"),
    ("Rates_of_Duty_2", "TEXT")
]
# For DictWriter-like mapping from processed data (keys should match map_extracted_row_to_target output)
MAPPED_DATA_KEYS = [
    "Page Number", # These keys are from map_extracted_row_to_target
    "Heading/Subheading",
    "Stat. Suffix",
    "Article Description",
    "Unit of Quantity",
    "Rates of Duty - General",
    "Rates of Duty - Special",
    "Rates of Duty - 2"
]


HTS_HEADER_KEYWORDS = [
    "heading/subheading", "heading/", "subheading", "stat.", "suf", "suffix",
    "article description", "article", "description",
    "unit of quantity", "unit", "quantity",
    "rates of duty", "rates", "duty", "general", "special"
]
MIN_HTS_HEADER_KEYWORDS_MATCH = 3
MIN_COLUMNS_FOR_HTS_TABLE = 5

# --- Helper Functions (clean_text, remove_footnote_markers, is_potential_hts_header_row - same as before) ---
def clean_text(text):
    if text is None: return ""
    return str(text).replace('\n', ' ').strip()

def remove_footnote_markers(text):
    if text is None: return ""
    return re.sub(r'\s*\d+/\s*', '', str(text)).strip()

def is_potential_hts_header_row(row_cells, keywords_list, min_matches):
    if not row_cells: return False
    combined_text = " ".join(filter(None, [str(c).lower() for c in row_cells]))
    match_count = 0
    for keyword in keywords_list:
        if keyword in combined_text:
            match_count += 1
    return match_count >= min_matches

def map_extracted_row_to_target_dict(raw_row_cells, page_num):
    """
    Maps raw cells to a dictionary with predefined keys (MAPPED_DATA_KEYS).
    This output dictionary's keys will be used for database insertion.
    """
    mapped_data = {key: "" for key in MAPPED_DATA_KEYS} # Initialize with all keys
    mapped_data["Page Number"] = page_num # Key from MAPPED_DATA_KEYS
    
    num_raw_cells = len(raw_row_cells)
    
    if num_raw_cells > 0: mapped_data["Heading/Subheading"] = remove_footnote_markers(clean_text(raw_row_cells[0]))
    if num_raw_cells > 1: mapped_data["Stat. Suffix"] = remove_footnote_markers(clean_text(raw_row_cells[1]))
    if num_raw_cells > 2: mapped_data["Article Description"] = remove_footnote_markers(clean_text(raw_row_cells[2]))
    if num_raw_cells > 3: mapped_data["Unit of Quantity"] = remove_footnote_markers(clean_text(raw_row_cells[3]))
    if num_raw_cells > 4: mapped_data["Rates of Duty - General"] = remove_footnote_markers(clean_text(raw_row_cells[4]))
    if num_raw_cells > 5: mapped_data["Rates of Duty - Special"] = remove_footnote_markers(clean_text(raw_row_cells[5]))
    if num_raw_cells > 6: mapped_data["Rates of Duty - 2"] = remove_footnote_markers(clean_text(raw_row_cells[6]))
    return mapped_data


def setup_database_if_needed(db_name, table_name, column_definitions):
    """Creates the SQLite database and table only if they don't exist."""
    db_exists = os.path.exists(db_name)
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    
    if db_exists:
        # Check if table exists in existing database
        cursor.execute(f"SELECT name FROM sqlite_master WHERE type='table' AND name='{table_name}';")
        if cursor.fetchone():
            print(f"Database '{db_name}' and table '{table_name}' already exist. Will append new data.")
            return conn, cursor
        else:
            print(f"Database exists but table '{table_name}' not found. Creating table...")
    else:
        print(f"Creating new database '{db_name}'...")
    
    # Create table if it doesn't exist
    cols_def_str = ", ".join([f'"{col_name}" {col_type}' for col_name, col_type in column_definitions])
    cursor.execute(f'''
        CREATE TABLE IF NOT EXISTS {table_name} (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            {cols_def_str}
        )
    ''')
    conn.commit()
    print(f"Table '{table_name}' ready in database '{db_name}'.")
    return conn, cursor

def insert_row_into_db(cursor, table_name, column_names_for_insert, data_dict):
    """Inserts a single row (as a dictionary) into the database."""
    # Ensure values are in the correct order corresponding to column_names_for_insert
    values_to_insert = [data_dict.get(key_from_mapped_data, "") for key_from_mapped_data in MAPPED_DATA_KEYS]
    
    placeholders = ', '.join(['?'] * len(column_names_for_insert))
    # column_names_for_insert are the actual DB column names (e.g., "Page_Number")
    cols_sql_str = ', '.join([f'"{col}"' for col in column_names_for_insert])

    sql = f"INSERT INTO {table_name} ({cols_sql_str}) VALUES ({placeholders})"
    cursor.execute(sql, values_to_insert)


def process_pdf_and_write_to_db(pdf_path, db_conn, db_cursor):
    """
    Processes PDF, identifies HTS tables, and writes data directly to SQLite.
    Memory optimized - processes one row at a time without storing in memory.
    Returns the total number of rows written.
    """
    rows_written_count = 0
    
    current_main_heading_context = ""
    current_subheading_base_context = ""
    
    db_column_names = [col_def[0] for col_def in DB_COLUMN_DEFINITIONS] # e.g., ["Page_Number", "Heading_Subheading", ...]

    if not os.path.exists(pdf_path):
        print(f"Error: PDF file not found at '{pdf_path}'")
        return 0

    try:
        with pdfplumber.open(pdf_path) as pdf:
            total_pages = len(pdf.pages)
            print(f"Starting processing of '{os.path.basename(pdf_path)}' ({total_pages} pages)...")
            print(f"Data will be written directly to SQLite table '{TABLE_NAME}' in '{DB_NAME}'")
            start_time = time.time()

            for i, page in enumerate(pdf.pages):
                page_num = i + 1
                if page_num % 50 == 0 or page_num == 1 or page_num == total_pages:
                    elapsed_time = time.time() - start_time
                    print(f"  Processing page {page_num}/{total_pages}... (Rows written so far: {rows_written_count}, Elapsed: {elapsed_time:.2f}s)")

                try:
                    tables = page.extract_tables(table_settings={
                        "vertical_strategy": "lines_strict", "horizontal_strategy": "lines_strict",
                        "snap_tolerance": 5, "join_tolerance": 5,
                    })
                    if not tables:
                        tables = page.extract_tables(table_settings={
                            "vertical_strategy": "text", "horizontal_strategy": "text",
                            "text_x_tolerance": 3, "text_y_tolerance": 3,
                            "snap_tolerance": 5, "join_tolerance": 5,
                        })
                except Exception:
                    tables = []

                if not tables:
                    continue

                for extracted_table in tables:
                    if not extracted_table or len(extracted_table) < 2 or len(extracted_table[0]) < MIN_COLUMNS_FOR_HTS_TABLE:
                        continue

                    header_row_index = -1
                    for r_idx, row_content in enumerate(extracted_table[:3]):
                        cleaned_row_cells = [clean_text(cell) for cell in row_content]
                        if is_potential_hts_header_row(cleaned_row_cells, HTS_HEADER_KEYWORDS, MIN_HTS_HEADER_KEYWORDS_MATCH):
                            header_row_index = r_idx
                            break
                    
                    if header_row_index == -1:
                        continue

                    for data_row_idx in range(header_row_index + 1, len(extracted_table)):
                        raw_data_cells = extracted_table[data_row_idx]
                        if not any(raw_data_cells) or not any(clean_text(c) for c in raw_data_cells):
                            continue
                        
                        mapped_row_dict = map_extracted_row_to_target_dict(raw_data_cells, page_num)

                        # --- HTS Specific Context Logic (Simplified - same as before) ---
                        hs_text = mapped_row_dict["Heading/Subheading"]
                        full_subheading = ""
                        if re.match(r'^\d{4}\.\d{2}\.\d{2}$', hs_text):
                            full_subheading = hs_text
                            current_main_heading_context = hs_text[:4]
                            current_subheading_base_context = hs_text
                        elif re.match(r'^\d{4}(\s*\(con\.\))?$', hs_text):
                            potential_main = hs_text.replace('(con.)','').strip()
                            if re.match(r'^\d{4}$', potential_main):
                                current_main_heading_context = potential_main
                            full_subheading = current_main_heading_context
                        elif hs_text:
                            if current_main_heading_context and re.match(r'^\s*\.\d{2}\.\d{2}$', hs_text.replace(current_main_heading_context, '', 1).strip()):
                                full_subheading = current_main_heading_context + hs_text.replace(current_main_heading_context, '', 1).strip()
                                current_subheading_base_context = full_subheading
                            else:
                                full_subheading = hs_text
                        
                        if not full_subheading and mapped_row_dict["Stat. Suffix"] and current_subheading_base_context:
                            full_subheading = current_subheading_base_context
                        elif not full_subheading and current_main_heading_context:
                            full_subheading = current_main_heading_context
                        
                        mapped_row_dict["Heading/Subheading"] = full_subheading
                        # --- End HTS Specific Context Logic ---
                        
                        essential_cols_check = [mapped_row_dict["Stat. Suffix"], 
                                       mapped_row_dict["Article Description"], 
                                       mapped_row_dict["Unit of Quantity"],
                                       mapped_row_dict["Rates of Duty - General"]]
                        
                        if any(essential_cols_check):
                            # Insert row immediately to database (no memory storage)
                            insert_row_into_db(db_cursor, TABLE_NAME, db_column_names, mapped_row_dict)
                            rows_written_count += 1
                            
                            # Commit every 100 rows for better performance and data safety
                            if rows_written_count % 100 == 0:
                                db_conn.commit()

            # Final commit for any remaining uncommitted rows
            db_conn.commit()
            total_time = time.time() - start_time
            print(f"  Finished processing all pages. Total time: {total_time:.2f}s")

    except Exception as e:
        print(f"An error occurred during PDF processing or DB writing: {e}")
        db_conn.rollback() # Rollback any uncommitted changes if error
    
    return rows_written_count

# %%
# --- Main Execution Code ---
pdf_file_path = "../data/raw/finalCopy.pdf"  # <--- SET YOUR PDF FILE PATH HERE

# Setup database - only creates if doesn't exist, otherwise just connects
db_connection, db_cursor = setup_database_if_needed(DB_NAME, TABLE_NAME, DB_COLUMN_DEFINITIONS)

total_rows = 0
if db_connection and db_cursor:
    try:
        total_rows = process_pdf_and_write_to_db(pdf_file_path, db_connection, db_cursor)
    except Exception as e:
        print(f"Error during processing: {e}")
    finally:
        db_connection.commit() # Final commit
        db_cursor.close()
        db_connection.close()
        print("Database connection closed.")

if total_rows > 0:
    print(f"\nSuccessfully processed PDF. {total_rows} HTS data rows written to SQLite.")
    print(f"Data saved to table '{TABLE_NAME}' in database '{DB_NAME}'")
else:
    print("\nNo HTS data rows were written to the database.")
# Out:
# Creating new database '../data/processed/fill_hts_schedule_data.db'...
# Table 'hts_entries' ready in database '../data/processed/fill_hts_schedule_data.db'.
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Starting processing of 'finalCopy.pdf' (4430 pages)...
# Data will be written directly to SQLite table 'hts_entries' in '../data/processed/fill_hts_schedule_data.db'
#   Processing page 1/4430... (Rows written so far: 0, Elapsed: 0.00s)
#   Processing page 50/4430... (Rows written so far: 0, Elapsed: 11.84s)
#   Processing page 100/4430... (Rows written so far: 0, Elapsed: 27.99s)
#   Processing page 150/4430... (Rows written so far: 0, Elapsed: 72.19s)
#   Processing page 200/4430... (Rows written so far: 0, Elapsed: 121.68s)
#   Processing page 250/4430... (Rows written so far: 0, Elapsed: 171.42s)
#   Processing page 300/4430... (Rows written so far: 0, Elapsed: 189.82s)
#   Processing page 350/4430... (Rows written so far: 0, Elapsed: 210.83s)
#   Processing page 400/4430... (Rows written so far: 0, Elapsed: 229.79s)
#   Processing page 450/4430... (Rows written so far: 0, Elapsed: 245.59s)
#   Processing page 500/4430... (Rows written so far: 0, Elapsed: 260.24s)
#   Processing page 550/4430... (Rows written so far: 0, Elapsed: 273.99s)
#   Processing page 600/4430... (Rows written so far: 0, Elapsed: 291.62s)
#   Processing page 650/4430... (Rows written so far: 0, Elapsed: 308.03s)
#   Processing page 700/4430... (Rows written so far: 0, Elapsed: 322.10s)
#   Processing page 750/4430... (Rows written so far: 0, Elapsed: 335.62s)
#   Processing page 800/4430... (Rows written so far: 0, Elapsed: 351.44s)
#   Processing page 850/4430... (Rows written so far: 0, Elapsed: 365.18s)
#   Processing page 900/4430... (Rows written so far: 0, Elapsed: 379.74s)
#   Processing page 950/4430... (Rows written so far: 1144, Elapsed: 389.28s)
#   Processing page 1000/4430... (Rows written so far: 2490, Elapsed: 398.14s)
#   Processing page 1050/4430... (Rows written so far: 3944, Elapsed: 403.85s)
#   Processing page 1100/4430... (Rows written so far: 5319, Elapsed: 413.56s)
#   Processing page 1150/4430... (Rows written so far: 6464, Elapsed: 421.03s)
#   Processing page 1200/4430... (Rows written so far: 7597, Elapsed: 432.57s)
#   Processing page 1250/4430... (Rows written so far: 9202, Elapsed: 451.13s)
#   Processing page 1300/4430... (Rows written so far: 10512, Elapsed: 477.52s)
#   Processing page 1350/4430... (Rows written so far: 11752, Elapsed: 496.68s)
#   Processing page 1400/4430... (Rows written so far: 12848, Elapsed: 504.60s)
#   Processing page 1450/4430... (Rows written so far: 13873, Elapsed: 513.12s)
#   Processing page 1500/4430... (Rows written so far: 14938, Elapsed: 520.31s)
#   Processing page 1550/4430... (Rows written so far: 16290, Elapsed: 527.38s)
#   Processing page 1600/4430... (Rows written so far: 17539, Elapsed: 534.64s)
#   Processing page 1650/4430... (Rows written so far: 18619, Elapsed: 558.66s)
#   Processing page 1700/4430... (Rows written so far: 19681, Elapsed: 567.23s)
#   Processing page 1750/4430... (Rows written so far: 20701, Elapsed: 573.85s)
#   Processing page 1800/4430... (Rows written so far: 21839, Elapsed: 580.06s)
#   Processing page 1850/4430... (Rows written so far: 23194, Elapsed: 587.44s)
#   Processing page 1900/4430... (Rows written so far: 24209, Elapsed: 595.63s)
#   Processing page 1950/4430... (Rows written so far: 25062, Elapsed: 603.63s)
#   Processing page 2000/4430... (Rows written so far: 26505, Elapsed: 646.71s)
#   Processing page 2050/4430... (Rows written so far: 28015, Elapsed: 654.58s)
#   Processing page 2100/4430... (Rows written so far: 29187, Elapsed: 660.96s)
#   Processing page 2150/4430... (Rows written so far: 30451, Elapsed: 668.37s)
#   Processing page 2200/4430... (Rows written so far: 32197, Elapsed: 674.69s)
#   Processing page 2250/4430... (Rows written so far: 33595, Elapsed: 681.95s)
#   Processing page 2300/4430... (Rows written so far: 35407, Elapsed: 693.28s)
#   Processing page 2350/4430... (Rows written so far: 37154, Elapsed: 706.36s)
#   Processing page 2400/4430... (Rows written so far: 38341, Elapsed: 715.88s)
#   Processing page 2450/4430... (Rows written so far: 39906, Elapsed: 722.63s)
#   Processing page 2500/4430... (Rows written so far: 40954, Elapsed: 797.55s)
#   Processing page 2550/4430... (Rows written so far: 42001, Elapsed: 805.13s)
#   Processing page 2600/4430... (Rows written so far: 42963, Elapsed: 814.45s)
#   Processing page 2650/4430... (Rows written so far: 44146, Elapsed: 822.31s)
#   Processing page 2700/4430... (Rows written so far: 45142, Elapsed: 828.31s)
#   Processing page 2750/4430... (Rows written so far: 46123, Elapsed: 836.75s)
#   Processing page 2800/4430... (Rows written so far: 47566, Elapsed: 845.76s)
#   Processing page 2850/4430... (Rows written so far: 49027, Elapsed: 854.45s)
#   Processing page 2900/4430... (Rows written so far: 50147, Elapsed: 953.42s)
#   Processing page 2950/4430... (Rows written so far: 51714, Elapsed: 963.28s)
#   Processing page 3000/4430... (Rows written so far: 52903, Elapsed: 971.40s)
#   Processing page 3050/4430... (Rows written so far: 54057, Elapsed: 979.10s)
#   Processing page 3100/4430... (Rows written so far: 54910, Elapsed: 987.17s)
#   Processing page 3150/4430... (Rows written so far: 56017, Elapsed: 995.42s)
#   Processing page 3200/4430... (Rows written so far: 56722, Elapsed: 1002.57s)
#   Processing page 3250/4430... (Rows written so far: 57416, Elapsed: 1013.09s)
#   Processing page 3300/4430... (Rows written so far: 57868, Elapsed: 1029.84s)
#   Processing page 3350/4430... (Rows written so far: 58974, Elapsed: 1234.06s)
#   Processing page 3400/4430... (Rows written so far: 60422, Elapsed: 1246.63s)
#   Processing page 3450/4430... (Rows written so far: 62091, Elapsed: 1259.76s)
#   Processing page 3500/4430... (Rows written so far: 63071, Elapsed: 1273.48s)
#   Processing page 3550/4430... (Rows written so far: 63183, Elapsed: 1292.51s)
#   Processing page 3600/4430... (Rows written so far: 63183, Elapsed: 1308.41s)
#   Processing page 3650/4430... (Rows written so far: 63183, Elapsed: 1602.92s)
#   Processing page 3700/4430... (Rows written so far: 63183, Elapsed: 1627.90s)
#   Processing page 3750/4430... (Rows written so far: 63183, Elapsed: 1653.62s)
#   Processing page 3800/4430... (Rows written so far: 63779, Elapsed: 1692.26s)
#   Processing page 3850/4430... (Rows written so far: 65406, Elapsed: 1706.10s)
#   Processing page 3900/4430... (Rows written so far: 66525, Elapsed: 1720.29s)
#   Processing page 3950/4430... (Rows written so far: 67324, Elapsed: 1737.50s)
#   Processing page 4000/4430... (Rows written so far: 68007, Elapsed: 1752.77s)
#   Processing page 4050/4430... (Rows written so far: 68051, Elapsed: 1769.51s)
#   Processing page 4100/4430... (Rows written so far: 68051, Elapsed: 2253.60s)
#   Processing page 4150/4430... (Rows written so far: 68051, Elapsed: 2272.08s)
#   Processing page 4200/4430... (Rows written so far: 68051, Elapsed: 2282.32s)
#   Processing page 4250/4430... (Rows written so far: 68051, Elapsed: 2288.85s)
#   Processing page 4300/4430... (Rows written so far: 68051, Elapsed: 2295.39s)
#   Processing page 4350/4430... (Rows written so far: 68051, Elapsed: 2303.59s)
#   Processing page 4400/4430... (Rows written so far: 68051, Elapsed: 2310.14s)
#   Processing page 4430/4430... (Rows written so far: 68051, Elapsed: 2314.11s)
#   Finished processing all pages. Total time: 2314.31s
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Database connection closed.
#
# Successfully processed PDF. 68051 HTS data rows written to SQLite.
# Data saved to table 'hts_entries' in database '../data/processed/fill_hts_schedule_data.db'

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect(DB_NAME)
df = pd.read_sql_query("SELECT * FROM hts_entries", conn)
conn.close()

# %%
df.shape
# Out:
# (68051, 9)
